# %%
pip install pymongo
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pymongo
#   Downloading pymongo-4.13.2-cp312-cp312-win_amd64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.13.2-cp312-cp312-win_amd64.whl (903 kB)
#    ---------------------------------------- 0.0/903.3 kB ? eta -:--:--
#    --------------------------------------- 903.3/903.3 kB 10.3 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install python-dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: python-dotenv in c:\programdata\anaconda3\lib\site-packages (0.21.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
print("Hello")
# Out:
# Hello

# %%
import tkinter
m = tkinter.Tk()
'''
widgets are added here
'''
m.mainloop()

# %%
import tkinter as tk

r = tk.Tk()
r.title('Counting Seconds')
button = tk.Button(r, text='Stop', width=25, command=r.destroy)
button.pack()
r.mainloop()

# %%
import tkinter as tk
from tkinter import ttk

def select(event):
    selected_item = combo_box.get()
    label.config(text="Selected Item: " + selected_item)

root = tk.Tk()
root.title("Combobox Example")

# Create a label
label = tk.Label(root, text="Selected Item: ")
label.pack(pady=10)

# Create a Combobox widget
combo_box = ttk.Combobox(root, values=["Option 1", "Option 2", "Option 3"])
combo_box.pack(pady=5)

# Set default value
combo_box.set("Option 1")

# Bind event to selection
combo_box.bind("<<ComboboxSelected>>", select)

root.mainloop()

# %%
import pandas as pd
import numpy as np

# Define the column names
columns = [
    "Material",
    "Youngs modulus",  # GPa
    "Poissons ratio",
    "Density",  # g/cm³
    "%EL",  # Percent elongation
    "UTS",  # Ultimate Tensile Strength (MPa)
    "Yield strength",  # MPa
    "Endurance Strength",  # MPa
    "Standard",
    "Hardness",  # HRB or HRC
    "Manufacturing process",
    "Applications"
]

# Sample data generator
data = {
    "Material": ["Steel", "Aluminum", "Copper", "Titanium", "Brass", "Nickel", "Magnesium", "Cast Iron", "Stainless Steel", "Bronze"],
    "Youngs modulus": [210, 70, 110, 116, 100, 200, 45, 120, 200, 110],  # GPa
    "Poissons ratio": [0.3, 0.33, 0.34, 0.32, 0.34, 0.31, 0.35, 0.25, 0.29, 0.34],
    "Density": [7.85, 2.70, 8.96, 4.51, 8.4, 8.9, 1.74, 7.2, 7.9, 8.8],  # g/cm³
    "%EL": [20, 12, 50, 14, 30, 40, 10, 2, 40, 15],
    "UTS": [550, 310, 210, 900, 350, 600, 250, 400, 520, 370],  # MPa
    "Yield strength": [250, 270, 70, 880, 200, 520, 150, 250, 210, 200],  # MPa
    "Endurance Strength": [200, 150, 80, 600, 120, 400, 90, 180, 220, 130],  # MPa
    "Standard": ["ASTM A36", "AA 6061", "C11000", "Grade 5", "C26000", "UNS N06600", "AZ31", "EN-GJL-250", "304", "C93200"],
    "Hardness": [150, 95, 60, 350, 130, 250, 70, 180, 200, 120],  # HRB or HRC approx.
    "Manufacturing process": [
        "Casting, Forging",
        "Extrusion, Rolling",
        "Rolling, Casting",
        "Forging, Machining",
        "Casting, Machining",
        "Casting, Rolling",
        "Extrusion",
        "Casting",
        "Rolling, Welding",
        "Casting"
    ],
    "Applications": [
        "Construction, Automotive",
        "Aerospace, Transportation",
        "Electrical wiring",
        "Aerospace, Medical implants",
        "Decorative, Plumbing",
        "Chemical equipment",
        "Automotive parts",
        "Pipes, Machinery",
        "Kitchenware, Medical",
        "Marine, Bearings"
    ]
}

# Create a DataFrame
df = pd.DataFrame(data, columns=columns)

# Save to Excel in the same folder as notebook
output_file = "sample_material_data.xlsx"
df.to_excel(output_file, index=False)

print(f"Sample data saved to '{output_file}'")
# Out:
# Sample data saved to 'sample_material_data.xlsx'

# %%
import pandas as pd
from openpyxl.utils import get_column_letter
from openpyxl import load_workbook

# Your DataFrame creation code here (same as before)

# Save DataFrame to Excel first
output_file = "sample_material_data.xlsx"
df.to_excel(output_file, index=False)

# Load workbook with openpyxl
wb = load_workbook(output_file)
ws = wb.active

# Auto-adjust column widths
for col_idx, col in enumerate(df.columns, 1):
    max_length = max(
        df[col].astype(str).map(len).max(),  # max length in column values
        len(col)  # header length
    )
    adjusted_width = max_length + 2  # extra space for padding
    ws.column_dimensions[get_column_letter(col_idx)].width = adjusted_width

# Save the workbook again
wb.save(output_file)

print(f"Saved Excel with auto-adjusted columns: {output_file}")
# Out:
# Saved Excel with auto-adjusted columns: sample_material_data.xlsx

# %%
import tkinter as tk
from tkinter import ttk
import pandas as pd

# Load the Excel data
df = pd.read_excel("sample_material_data.xlsx")

# Create the main window
root = tk.Tk()
root.title("Material Data")

# Create a frame for the Treeview and scrollbar
frame = ttk.Frame(root)
frame.pack(fill='both', expand=True)

# Create Treeview widget
tree = ttk.Treeview(frame, columns=list(df.columns), show='headings')

# Define headings and column widths
for col in df.columns:
    tree.heading(col, text=col)
    tree.column(col, width=120, anchor='center')  # adjust width as needed

# Insert data rows
for _, row in df.iterrows():
    tree.insert('', tk.END, values=list(row))

# Add vertical scrollbar
vsb = ttk.Scrollbar(frame, orient="vertical", command=tree.yview)
tree.configure(yscrollcommand=vsb.set)
vsb.pack(side='right', fill='y')

# Add horizontal scrollbar
hsb = ttk.Scrollbar(frame, orient="horizontal", command=tree.xview)
tree.configure(xscrollcommand=hsb.set)
hsb.pack(side='bottom', fill='x')

tree.pack(fill='both', expand=True)

# Start the GUI event loop
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
import pandas as pd

# Load the Excel data
df = pd.read_excel("sample_material_data.xlsx")

# Create the main window
root = tk.Tk()
root.title("Material Data")

# Create a frame for the Treeview and scrollbar
frame = ttk.Frame(root)
frame.pack(fill='both', expand=True)

# Create Treeview widget
tree = ttk.Treeview(frame, columns=list(df.columns), show='headings')

# Define headings and column widths
for col in df.columns:
    tree.heading(col, text=col)
    tree.column(col, width=120, anchor='center')  # adjust width as needed

# Insert data rows
for _, row in df.iterrows():
    tree.insert('', tk.END, values=list(row))

# Add vertical scrollbar
vsb = ttk.Scrollbar(frame, orient="vertical", command=tree.yview)
tree.configure(yscrollcommand=vsb.set)
vsb.pack(side='right', fill='y')

# Add horizontal scrollbar
hsb = ttk.Scrollbar(frame, orient="horizontal", command=tree.xview)
tree.configure(xscrollcommand=hsb.set)
hsb.pack(side='bottom', fill='x')

tree.pack(fill='both', expand=True)

# Start the GUI event loop
root.mainloop()

# %%
import pandas as pd
import numpy as np

# Column names
columns = [
    "Material",
    "Youngs modulus",
    "Poissons ratio",
    "Density",
    "%EL",
    "UTS",
    "Yield strength",
    "Endurance Strength",
    "Standard",
    "Hardness",
    "Manufacturing process",
    "Applications"
]

# Possible sample options for categorical fields
materials = ["Steel", "Aluminum", "Copper", "Titanium", "Brass", "Nickel", "Magnesium", "Cast Iron", "Stainless Steel", "Bronze"]
standards = ["ASTM A36", "AA 6061", "C11000", "Grade 5", "C26000", "UNS N06600", "AZ31", "EN-GJL-250", "304", "C93200"]
processes = ["Casting", "Forging", "Extrusion", "Rolling", "Machining", "Welding"]
applications = [
    "Construction", "Automotive", "Aerospace", "Electrical wiring",
    "Medical implants", "Decorative", "Chemical equipment", "Pipes",
    "Kitchenware", "Marine"
]

num_rows = 50

np.random.seed(42)  # for reproducibility

data = {
    "Material": np.random.choice(materials, num_rows),
    "Youngs modulus": np.round(np.random.uniform(40, 220, num_rows), 1),  # GPa
    "Poissons ratio": np.round(np.random.uniform(0.25, 0.35, num_rows), 3),
    "Density": np.round(np.random.uniform(1.7, 8.9, num_rows), 2),  # g/cm³
    "%EL": np.round(np.random.uniform(2, 50, num_rows), 1),
    "UTS": np.round(np.random.uniform(150, 950, num_rows), 0),  # MPa
    "Yield strength": np.round(np.random.uniform(50, 900, num_rows), 0),  # MPa
    "Endurance Strength": np.round(np.random.uniform(50, 650, num_rows), 0),  # MPa
    "Standard": np.random.choice(standards, num_rows),
    "Hardness": np.round(np.random.uniform(60, 350, num_rows), 0),  # HRB or HRC
    "Manufacturing process": np.random.choice(processes, num_rows),
    "Applications": np.random.choice(applications, num_rows)
}

df = pd.DataFrame(data, columns=columns)

# Save to Excel
output_file = "sample_material_data.xlsx"
df.to_excel(output_file, index=False)

print(f"Excel with {num_rows} rows saved as '{output_file}'")
# Out:
# Excel with 50 rows saved as 'sample_material_data.xlsx'

# %%
import tkinter as tk
from tkinter import ttk
import pandas as pd

# Load the Excel data
df = pd.read_excel("sample_material_data.xlsx")

# Create the main window
root = tk.Tk()
root.title("Material Data")

# Create a frame for the Treeview and scrollbar
frame = ttk.Frame(root)
frame.pack(fill='both', expand=True)

# Create Treeview widget
tree = ttk.Treeview(frame, columns=list(df.columns), show='headings')

# Define headings and column widths
for col in df.columns:
    tree.heading(col, text=col)
    tree.column(col, width=120, anchor='center')  # adjust width as needed

# Insert data rows
for _, row in df.iterrows():
    tree.insert('', tk.END, values=list(row))

# Add vertical scrollbar
vsb = ttk.Scrollbar(frame, orient="vertical", command=tree.yview)
tree.configure(yscrollcommand=vsb.set)
vsb.pack(side='right', fill='y')

# Add horizontal scrollbar
hsb = ttk.Scrollbar(frame, orient="horizontal", command=tree.xview)
tree.configure(xscrollcommand=hsb.set)
hsb.pack(side='bottom', fill='x')

tree.pack(fill='both', expand=True)

# Start the GUI event loop
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
import pandas as pd

# Load the Excel data
df = pd.read_excel("sample_material_data.xlsx")

# Create the main window
root = tk.Tk()
root.title("Material Data")
root.geometry("1200x600")  # Set a decent window size
root.configure(bg="#f0f0f0")  # Light gray background

# Style configuration
style = ttk.Style(root)
style.theme_use('clam')  # Use a modern theme

# Customize Treeview colors
style.configure("Treeview",
                background="white",
                foreground="black",
                rowheight=25,
                fieldbackground="white",
                font=('Segoe UI', 10))

style.map('Treeview', background=[('selected', '#347083')], foreground=[('selected', 'white')])

# Header style
style.configure("Treeview.Heading",
                font=('Segoe UI', 11, 'bold'),
                background="#4a7abc",
                foreground="white")

# Create a frame for Treeview and Scrollbars with padding
frame = ttk.Frame(root, padding=10)
frame.pack(fill='both', expand=True)

# Create Treeview widget with columns from dataframe
tree = ttk.Treeview(frame, columns=list(df.columns), show='headings')

# Define headings and column widths
for col in df.columns:
    tree.heading(col, text=col)
    tree.column(col, width=110, anchor='center')

# Add data rows with alternating colors
for i, (_, row) in enumerate(df.iterrows()):
    if i % 2 == 0:
        tree.insert('', 'end', values=list(row), tags=('evenrow',))
    else:
        tree.insert('', 'end', values=list(row), tags=('oddrow',))

# Tag configurations for alternating row colors
tree.tag_configure('evenrow', background='white')
tree.tag_configure('oddrow', background='#e6f2ff')  # Light blue

# Add vertical scrollbar
vsb = ttk.Scrollbar(frame, orient="vertical", command=tree.yview)
tree.configure(yscrollcommand=vsb.set)
vsb.pack(side='right', fill='y')

# Add horizontal scrollbar
hsb = ttk.Scrollbar(frame, orient="horizontal", command=tree.xview)
tree.configure(xscrollcommand=hsb.set)
hsb.pack(side='bottom', fill='x')

tree.pack(fill='both', expand=True)

# Run the application
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
import pandas as pd

# Load the Excel data
df = pd.read_excel("sample_material_data.xlsx")

# Create the main window
root = tk.Tk()
root.title("Material Data")
root.geometry("1200x600")
root.configure(bg="#f0f0f0")

# Style configuration
style = ttk.Style(root)
style.theme_use('clam')

style.configure("Treeview",
                background="white",
                foreground="black",
                rowheight=25,
                fieldbackground="white",
                font=('Segoe UI', 10))

style.map('Treeview', background=[('selected', '#347083')], foreground=[('selected', 'white')])

style.configure("Treeview.Heading",
                font=('Segoe UI', 11, 'bold'),
                background="#4a7abc",
                foreground="white")

# Frame for Search + Treeview
main_frame = ttk.Frame(root, padding=10)
main_frame.pack(fill='both', expand=True)

# Search label and entry
search_frame = ttk.Frame(main_frame)
search_frame.pack(fill='x', pady=(0, 10))

ttk.Label(search_frame, text="Search Material:", font=('Segoe UI', 11)).pack(side='left', padx=(0, 5))

search_var = tk.StringVar()

search_entry = ttk.Entry(search_frame, textvariable=search_var, font=('Segoe UI', 11), width=30)
search_entry.pack(side='left')

# Create Treeview widget
tree = ttk.Treeview(main_frame, columns=list(df.columns), show='headings')

# Define headings and column widths
for col in df.columns:
    tree.heading(col, text=col)
    tree.column(col, width=110, anchor='center')

# Add scrollbars
vsb = ttk.Scrollbar(main_frame, orient="vertical", command=tree.yview)
hsb = ttk.Scrollbar(main_frame, orient="horizontal", command=tree.xview)
tree.configure(yscrollcommand=vsb.set, xscrollcommand=hsb.set)

vsb.pack(side='right', fill='y')
hsb.pack(side='bottom', fill='x')
tree.pack(fill='both', expand=True)

# Function to display data in Treeview with alternating colors
def display_data(dataframe):
    tree.delete(*tree.get_children())
    for i, (_, row) in enumerate(dataframe.iterrows()):
        tag = 'evenrow' if i % 2 == 0 else 'oddrow'
        tree.insert('', 'end', values=list(row), tags=(tag,))
    tree.tag_configure('evenrow', background='white')
    tree.tag_configure('oddrow', background='#e6f2ff')

# Initial load of all data
display_data(df)

# Search/filter function
def on_search(*args):
    search_text = search_var.get().strip().lower()
    if search_text == "":
        filtered_df = df
    else:
        filtered_df = df[df['Material'].str.lower().str.contains(search_text)]
    display_data(filtered_df)

# Bind search_var to call on_search whenever it changes
search_var.trace_add('write', on_search)

root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
import pandas as pd

# Load the Excel data
df = pd.read_excel("sample_material_data.xlsx")

# Create main window
root = tk.Tk()
root.title("Material Data")
root.geometry("1200x650")
root.configure(bg="#f0f0f0")

# Style configuration
style = ttk.Style(root)
style.theme_use('clam')

style.configure("Treeview",
                background="white",
                foreground="black",
                rowheight=25,
                fieldbackground="white",
                font=('Segoe UI', 10),
                bordercolor='gray',
                borderwidth=1)

style.map('Treeview', background=[('selected', '#347083')], foreground=[('selected', 'white')])

style.configure("Treeview.Heading",
                font=('Segoe UI', 11, 'bold'),
                background="#4a7abc",
                foreground="white",
                relief="raised")

# Frame for Search + Treeview
main_frame = ttk.Frame(root, padding=10)
main_frame.pack(fill='both', expand=True)

# Search Frame with label, dropdown and entry
search_frame = ttk.Frame(main_frame)
search_frame.pack(fill='x', pady=(0, 10))

ttk.Label(search_frame, text="Search in:", font=('Segoe UI', 11)).pack(side='left', padx=(0, 5))

search_column = tk.StringVar(value=df.columns[0])
search_column_cb = ttk.Combobox(search_frame, textvariable=search_column, values=list(df.columns), state='readonly', width=25, font=('Segoe UI', 11))
search_column_cb.pack(side='left', padx=(0, 15))

ttk.Label(search_frame, text="Search for:", font=('Segoe UI', 11)).pack(side='left', padx=(0, 5))

search_var = tk.StringVar()
search_entry = ttk.Entry(search_frame, textvariable=search_var, font=('Segoe UI', 11), width=30)
search_entry.pack(side='left')

# Create Treeview widget with show='headings' and show vertical lines
tree = ttk.Treeview(main_frame, columns=list(df.columns), show='headings')

# Define headings and column widths and enable vertical lines with 'show=headings'
for col in df.columns:
    tree.heading(col, text=col)
    tree.column(col, width=110, anchor='center')

# Add scrollbars
vsb = ttk.Scrollbar(main_frame, orient="vertical", command=tree.yview)
hsb = ttk.Scrollbar(main_frame, orient="horizontal", command=tree.xview)
tree.configure(yscrollcommand=vsb.set, xscrollcommand=hsb.set)

vsb.pack(side='right', fill='y')
hsb.pack(side='bottom', fill='x')
tree.pack(fill='both', expand=True)

# Function to display data in Treeview with alternating colors
def display_data(dataframe):
    tree.delete(*tree.get_children())
    for i, (_, row) in enumerate(dataframe.iterrows()):
        tag = 'evenrow' if i % 2 == 0 else 'oddrow'
        tree.insert('', 'end', values=list(row), tags=(tag,))
    tree.tag_configure('evenrow', background='white')
    tree.tag_configure('oddrow', background='#e6f2ff')

# Initial load of all data
display_data(df)

# Advanced search/filter function based on selected column
def on_search(*args):
    search_text = search_var.get().strip().lower()
    col = search_column.get()
    if search_text == "":
        filtered_df = df
    else:
        # Handle missing values safely
        filtered_df = df[df[col].astype(str).str.lower().str.contains(search_text)]
    display_data(filtered_df)

# Bind the search_var and search_column to update results on change
search_var.trace_add('write', on_search)
search_column_cb.bind('<<ComboboxSelected>>', lambda e: on_search())

root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
import pandas as pd

# Load the Excel data
df = pd.read_excel("sample_material_data.xlsx")

# Create main window
root = tk.Tk()
root.title("Material Data")
root.geometry("1200x650")
root.configure(bg="#f0f0f0")

# Style configuration
style = ttk.Style(root)
style.theme_use('clam')

style.configure("Treeview",
                background="white",
                foreground="black",
                rowheight=25,
                fieldbackground="white",
                font=('Segoe UI', 10),
                bordercolor='gray',
                borderwidth=1)

style.map('Treeview', background=[('selected', '#347083')], foreground=[('selected', 'white')])

style.configure("Treeview.Heading",
                font=('Segoe UI', 11, 'bold'),
                background="#4a7abc",
                foreground="white",
                relief="raised")

# Frame for Search + Treeview
main_frame = ttk.Frame(root, padding=10)
main_frame.pack(fill='both', expand=True)

# Search Frame with label, dropdown and entry
search_frame = ttk.Frame(main_frame)
search_frame.pack(fill='x', pady=(0, 10))

ttk.Label(search_frame, text="Search in:", font=('Segoe UI', 11)).pack(side='left', padx=(0, 5))

search_column = tk.StringVar(value=df.columns[0])
search_column_cb = ttk.Combobox(search_frame, textvariable=search_column, values=list(df.columns), state='readonly', width=25, font=('Segoe UI', 11))
search_column_cb.pack(side='left', padx=(0, 15))

ttk.Label(search_frame, text="Search for:", font=('Segoe UI', 11)).pack(side='left', padx=(0, 5))

search_var = tk.StringVar()
search_entry = ttk.Entry(search_frame, textvariable=search_var, font=('Segoe UI', 11), width=30)
search_entry.pack(side='left')

# Create Treeview widget with show='headings' and show vertical lines
tree = ttk.Treeview(main_frame, columns=list(df.columns), show='headings')

# Define headings and column widths and enable vertical lines with 'show=headings'
for col in df.columns:
    tree.heading(col, text=col)
    tree.column(col, width=110, anchor='center')

# Add scrollbars
vsb = ttk.Scrollbar(main_frame, orient="vertical", command=tree.yview)
hsb = ttk.Scrollbar(main_frame, orient="horizontal", command=tree.xview)
tree.configure(yscrollcommand=vsb.set, xscrollcommand=hsb.set)

vsb.pack(side='right', fill='y')
hsb.pack(side='bottom', fill='x')
tree.pack(fill='both', expand=True)

# Function to display data in Treeview with alternating colors
def display_data(dataframe):
    tree.delete(*tree.get_children())
    for i, (_, row) in enumerate(dataframe.iterrows()):
        tag = 'evenrow' if i % 2 == 0 else 'oddrow'
        tree.insert('', 'end', values=list(row), tags=(tag,))
    tree.tag_configure('evenrow', background='white')
    tree.tag_configure('oddrow', background='#e6f2ff')

# Initial load of all data
display_data(df)

# Advanced search/filter function based on selected column
def on_search(*args):
    search_text = search_var.get().strip().lower()
    col = search_column.get()
    if search_text == "":
        filtered_df = df
    else:
        # Handle missing values safely
        filtered_df = df[df[col].astype(str).str.lower().str.contains(search_text)]
    display_data(filtered_df)

# Bind the search_var and search_column to update results on change
search_var.trace_add('write', on_search)
search_column_cb.bind('<<ComboboxSelected>>', lambda e: on_search())

root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
import pandas as pd

# Load the Excel data
df = pd.read_excel("sample_material_data.xlsx")

# Create main window
root = tk.Tk()
root.title("Material Data")
root.geometry("1200x650")
root.configure(bg="#f0f0f0")

# Style configuration
style = ttk.Style(root)
style.theme_use('clam')

style.configure("Treeview",
                background="white",
                foreground="black",
                rowheight=25,
                fieldbackground="white",
                font=('Segoe UI', 10),
                bordercolor='gray',
                borderwidth=1)

style.map('Treeview', background=[('selected', '#347083')], foreground=[('selected', 'white')])

style.configure("Treeview.Heading",
                font=('Segoe UI', 11, 'bold'),
                background="#4a7abc",
                foreground="white",
                relief="raised")

# Frame for Search + Treeview
main_frame = ttk.Frame(root, padding=10)
main_frame.pack(fill='both', expand=True)

# Search Frame with label, dropdown and entry
search_frame = ttk.Frame(main_frame)
search_frame.pack(fill='x', pady=(0, 10))

ttk.Label(search_frame, text="Search in:", font=('Segoe UI', 11)).pack(side='left', padx=(0, 5))

search_column = tk.StringVar(value=df.columns[0])
search_column_cb = ttk.Combobox(search_frame, textvariable=search_column, values=list(df.columns), state='readonly', width=25, font=('Segoe UI', 11))
search_column_cb.pack(side='left', padx=(0, 15))

ttk.Label(search_frame, text="Search for:", font=('Segoe UI', 11)).pack(side='left', padx=(0, 5))

search_var = tk.StringVar()
search_entry = ttk.Entry(search_frame, textvariable=search_var, font=('Segoe UI', 11), width=30)
search_entry.pack(side='left')

# Create Treeview widget with show='headings' and show vertical lines
tree = ttk.Treeview(main_frame, columns=list(df.columns), show='headings')

# Define headings and column widths and enable vertical lines with 'show=headings'
for col in df.columns:
    tree.heading(col, text=col)
    tree.column(col, width=110, anchor='center')

# Add scrollbars
vsb = ttk.Scrollbar(main_frame, orient="vertical", command=tree.yview)
hsb = ttk.Scrollbar(main_frame, orient="horizontal", command=tree.xview)
tree.configure(yscrollcommand=vsb.set, xscrollcommand=hsb.set)

vsb.pack(side='right', fill='y')
hsb.pack(side='bottom', fill='x')
tree.pack(fill='both', expand=True)

# Function to display data in Treeview with alternating colors
def display_data(dataframe):
    tree.delete(*tree.get_children())
    for i, (_, row) in enumerate(dataframe.iterrows()):
        tag = 'evenrow' if i % 2 == 0 else 'oddrow'
        tree.insert('', 'end', values=list(row), tags=(tag,))
    tree.tag_configure('evenrow', background='white')
    tree.tag_configure('oddrow', background='#e6f2ff')

# Initial load of all data
display_data(df)

# Advanced search/filter function based on selected column
def on_search(*args):
    search_text = search_var.get().strip().lower()
    col = search_column.get()
    if search_text == "":
        filtered_df = df
    else:
        # Handle missing values safely
        filtered_df = df[df[col].astype(str).str.lower().str.contains(search_text)]
    display_data(filtered_df)

# Bind the search_var and search_column to update results on change
search_var.trace_add('write', on_search)
search_column_cb.bind('<<ComboboxSelected>>', lambda e: on_search())

root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
import pandas as pd

# Load the Excel data
df = pd.read_excel("sample_material_data.xlsx")

# Create the main window
root = tk.Tk()
root.title("Material Data")
root.geometry("1200x600")
root.configure(bg="#f0f0f0")

# Style configuration
style = ttk.Style(root)
style.theme_use('clam')

style.configure("Treeview",
                background="white",
                foreground="black",
                rowheight=25,
                fieldbackground="white",
                font=('Segoe UI', 10))

style.map('Treeview', background=[('selected', '#347083')], foreground=[('selected', 'white')])

style.configure("Treeview.Heading",
                font=('Segoe UI', 11, 'bold'),
                background="#4a7abc",
                foreground="white")

# Frame for Search + Treeview
main_frame = ttk.Frame(root, padding=10)
main_frame.pack(fill='both', expand=True)

# Search label and entry
search_frame = ttk.Frame(main_frame)
search_frame.pack(fill='x', pady=(0, 10))

ttk.Label(search_frame, text="Search Material:", font=('Segoe UI', 11)).pack(side='left', padx=(0, 5))

search_var = tk.StringVar()

search_entry = ttk.Entry(search_frame, textvariable=search_var, font=('Segoe UI', 11), width=30)
search_entry.pack(side='left')

# Create Treeview widget
tree = ttk.Treeview(main_frame, columns=list(df.columns), show='headings')

# Define headings and column widths
for col in df.columns:
    tree.heading(col, text=col)
    tree.column(col, width=110, anchor='center')

# Add scrollbars
vsb = ttk.Scrollbar(main_frame, orient="vertical", command=tree.yview)
hsb = ttk.Scrollbar(main_frame, orient="horizontal", command=tree.xview)
tree.configure(yscrollcommand=vsb.set, xscrollcommand=hsb.set)

vsb.pack(side='right', fill='y')
hsb.pack(side='bottom', fill='x')
tree.pack(fill='both', expand=True)

# Function to display data in Treeview with alternating colors
def display_data(dataframe):
    tree.delete(*tree.get_children())
    for i, (_, row) in enumerate(dataframe.iterrows()):
        tag = 'evenrow' if i % 2 == 0 else 'oddrow'
        tree.insert('', 'end', values=list(row), tags=(tag,))
    tree.tag_configure('evenrow', background='white')
    tree.tag_configure('oddrow', background='#e6f2ff')

# Initial load of all data
display_data(df)

# Search/filter function
def on_search(*args):
    search_text = search_var.get().strip().lower()
    if search_text == "":
        filtered_df = df
    else:
        filtered_df = df[df['Material'].str.lower().str.contains(search_text)]
    display_data(filtered_df)

# Bind search_var to call on_search whenever it changes
search_var.trace_add('write', on_search)

root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
import pandas as pd

# Load the Excel data
df = pd.read_excel("sample_material_data.xlsx")

# Create the main window
root = tk.Tk()
root.title("Material Data")
root.geometry("1200x650")
root.configure(bg="#f0f0f0")

# Style configuration
style = ttk.Style(root)
style.theme_use('clam')

style.configure("Treeview",
                background="white",
                foreground="black",
                rowheight=25,
                fieldbackground="white",
                font=('Segoe UI', 10))

style.map('Treeview', background=[('selected', '#347083')], foreground=[('selected', 'white')])

style.configure("Treeview.Heading",
                font=('Segoe UI', 11, 'bold'),
                background="#4a7abc",
                foreground="white")

# Frame for Search + Treeview
main_frame = ttk.Frame(root, padding=10)
main_frame.pack(fill='both', expand=True)

# Search frame
search_frame = ttk.Frame(main_frame)
search_frame.pack(fill='x', pady=(0, 10))

# Search by Material
ttk.Label(search_frame, text="Search Material:", font=('Segoe UI', 11)).pack(side='left', padx=(0, 5))
search_var = tk.StringVar()
search_entry = ttk.Entry(search_frame, textvariable=search_var, font=('Segoe UI', 11), width=30)
search_entry.pack(side='left', padx=(0, 20))

# Sorting dropdown
ttk.Label(search_frame, text="Sort by:", font=('Segoe UI', 11)).pack(side='left')
sort_var = tk.StringVar()
sort_options = ["Youngs modulus", "Poissons ratio", "UTS", "Yield strength", "Endurance Strength"]
sort_combobox = ttk.Combobox(search_frame, textvariable=sort_var, values=sort_options, state='readonly', width=25, font=('Segoe UI', 10))
sort_combobox.set("Select a column")
sort_combobox.pack(side='left')

# Treeview widget
tree = ttk.Treeview(main_frame, columns=list(df.columns), show='headings')

# Define headings and column widths
for col in df.columns:
    tree.heading(col, text=col)
    tree.column(col, width=110, anchor='center')

# Add scrollbars
vsb = ttk.Scrollbar(main_frame, orient="vertical", command=tree.yview)
hsb = ttk.Scrollbar(main_frame, orient="horizontal", command=tree.xview)
tree.configure(yscrollcommand=vsb.set, xscrollcommand=hsb.set)
vsb.pack(side='right', fill='y')
hsb.pack(side='bottom', fill='x')
tree.pack(fill='both', expand=True)

# Display function
def display_data(dataframe):
    tree.delete(*tree.get_children())
    for i, (_, row) in enumerate(dataframe.iterrows()):
        tag = 'evenrow' if i % 2 == 0 else 'oddrow'
        tree.insert('', 'end', values=list(row), tags=(tag,))
    tree.tag_configure('evenrow', background='white')
    tree.tag_configure('oddrow', background='#e6f2ff')

# Initial load
display_data(df)

# Filter and sort logic
def update_view(*args):
    filtered_df = df.copy()
    
    # Filter by Material
    search_text = search_var.get().strip().lower()
    if search_text != "":
        filtered_df = filtered_df[filtered_df['Material'].str.lower().str.contains(search_text)]

    # Sort if a valid column is selected
    sort_column = sort_var.get()
    if sort_column in sort_options:
        try:
            filtered_df = filtered_df.sort_values(by=sort_column, ascending=True)
        except Exception as e:
            print(f"Sorting error: {e}")

    display_data(filtered_df)

# Bind triggers
search_var.trace_add('write', update_view)
sort_combobox.bind('<<ComboboxSelected>>', update_view)

# Main loop
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
import pandas as pd

# Load the Excel data
df = pd.read_excel("sample_material_data.xlsx")

# Create the main window
root = tk.Tk()
root.title("Material Data")
root.geometry("1250x700")
root.configure(bg="#f0f0f0")

# Style configuration
style = ttk.Style(root)
style.theme_use('clam')

style.configure("Treeview",
                background="white",
                foreground="black",
                rowheight=25,
                fieldbackground="white",
                font=('Segoe UI', 10))

style.map('Treeview', background=[('selected', '#347083')], foreground=[('selected', 'white')])

style.configure("Treeview.Heading",
                font=('Segoe UI', 11, 'bold'),
                background="#4a7abc",
                foreground="white")

# Frame for Search + Treeview
main_frame = ttk.Frame(root, padding=10)
main_frame.pack(fill='both', expand=True)

# Search and filter frame
search_frame = ttk.Frame(main_frame)
search_frame.pack(fill='x', pady=(0, 10))

# Search by Material
ttk.Label(search_frame, text="Search Material:", font=('Segoe UI', 11)).pack(side='left', padx=(0, 5))
search_var = tk.StringVar()
search_entry = ttk.Entry(search_frame, textvariable=search_var, font=('Segoe UI', 11), width=30)
search_entry.pack(side='left', padx=(0, 20))

# Sorting dropdown
ttk.Label(search_frame, text="Sort by:", font=('Segoe UI', 11)).pack(side='left')
sort_var = tk.StringVar()
sort_options = ["Youngs modulus", "Poissons ratio", "UTS", "Yield strength", "Endurance Strength"]
sort_combobox = ttk.Combobox(search_frame, textvariable=sort_var, values=sort_options, state='readonly', width=25, font=('Segoe UI', 10))
sort_combobox.set("Select a column")
sort_combobox.pack(side='left', padx=(0, 20))

# Manufacturing process filter
ttk.Label(search_frame, text="Filter Manufacturing Process:", font=('Segoe UI', 11)).pack(side='left')
mfg_process_var = tk.StringVar()
mfg_process_options = ["All"] + sorted(df['Manufacturing process'].dropna().unique().tolist())
mfg_process_combobox = ttk.Combobox(search_frame, textvariable=mfg_process_var, values=mfg_process_options, state='readonly', width=25, font=('Segoe UI', 10))
mfg_process_combobox.set("All")
mfg_process_combobox.pack(side='left', padx=(0, 20))

# Applications filter
ttk.Label(search_frame, text="Filter Applications:", font=('Segoe UI', 11)).pack(side='left')
applications_var = tk.StringVar()
applications_options = ["All"] + sorted(df['Applications'].dropna().unique().tolist())
applications_combobox = ttk.Combobox(search_frame, textvariable=applications_var, values=applications_options, state='readonly', width=25, font=('Segoe UI', 10))
applications_combobox.set("All")
applications_combobox.pack(side='left')

# Treeview widget
tree = ttk.Treeview(main_frame, columns=list(df.columns), show='headings')

# Define headings and column widths
for col in df.columns:
    tree.heading(col, text=col)
    tree.column(col, width=110, anchor='center')

# Add scrollbars
vsb = ttk.Scrollbar(main_frame, orient="vertical", command=tree.yview)
hsb = ttk.Scrollbar(main_frame, orient="horizontal", command=tree.xview)
tree.configure(yscrollcommand=vsb.set, xscrollcommand=hsb.set)
vsb.pack(side='right', fill='y')
hsb.pack(side='bottom', fill='x')
tree.pack(fill='both', expand=True)

# Display function
def display_data(dataframe):
    tree.delete(*tree.get_children())
    for i, (_, row) in enumerate(dataframe.iterrows()):
        tag = 'evenrow' if i % 2 == 0 else 'oddrow'
        tree.insert('', 'end', values=list(row), tags=(tag,))
    tree.tag_configure('evenrow', background='white')
    tree.tag_configure('oddrow', background='#e6f2ff')

# Initial load
display_data(df)

# Update function with filters, search and sort
def update_view(*args):
    filtered_df = df.copy()

    # Filter by Material search
    search_text = search_var.get().strip().lower()
    if search_text != "":
        filtered_df = filtered_df[filtered_df['Material'].str.lower().str.contains(search_text)]

    # Filter by Manufacturing process if not "All"
    mfg_value = mfg_process_var.get()
    if mfg_value != "All":
        filtered_df = filtered_df[filtered_df['Manufacturing process'] == mfg_value]

    # Filter by Applications if not "All"
    app_value = applications_var.get()
    if app_value != "All":
        filtered_df = filtered_df[filtered_df['Applications'] == app_value]

    # Sort if selected
    sort_column = sort_var.get()
    if sort_column in sort_options:
        try:
            filtered_df = filtered_df.sort_values(by=sort_column, ascending=True)
        except Exception as e:
            print(f"Sorting error: {e}")

    display_data(filtered_df)

# Bind all filters and search to update view on change
search_var.trace_add('write', update_view)
sort_combobox.bind('<<ComboboxSelected>>', update_view)
mfg_process_combobox.bind('<<ComboboxSelected>>', update_view)
applications_combobox.bind('<<ComboboxSelected>>', update_view)

root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
import pandas as pd

# Load the Excel data
df = pd.read_excel("sample_material_data.xlsx")

# Create the main window
root = tk.Tk()
root.title("Material Data")
root.geometry("1250x750")
root.configure(bg="#f0f0f0")

# Style configuration (same as before)
style = ttk.Style(root)
style.theme_use('clam')

style.configure("Treeview",
                background="white",
                foreground="black",
                rowheight=25,
                fieldbackground="white",
                font=('Segoe UI', 10))

style.map('Treeview', background=[('selected', '#347083')], foreground=[('selected', 'white')])

style.configure("Treeview.Heading",
                font=('Segoe UI', 11, 'bold'),
                background="#4a7abc",
                foreground="white")

# Frame for Search + Treeview
main_frame = ttk.Frame(root, padding=10)
main_frame.pack(fill='both', expand=True)

# Search and filter frame
search_frame = ttk.Frame(main_frame)
search_frame.pack(fill='x', pady=(0, 10))

# --- Existing Search and Filters ---

# Search by Material
ttk.Label(search_frame, text="Search Material:", font=('Segoe UI', 11)).pack(side='left', padx=(0, 5))
search_var = tk.StringVar()
search_entry = ttk.Entry(search_frame, textvariable=search_var, font=('Segoe UI', 11), width=30)
search_entry.pack(side='left', padx=(0, 20))

# Sorting dropdown
ttk.Label(search_frame, text="Sort by:", font=('Segoe UI', 11)).pack(side='left')
sort_var = tk.StringVar()
sort_options = ["Youngs modulus", "Poissons ratio", "UTS", "Yield strength", "Endurance Strength"]
sort_combobox = ttk.Combobox(search_frame, textvariable=sort_var, values=sort_options, state='readonly', width=25, font=('Segoe UI', 10))
sort_combobox.set("Select a column")
sort_combobox.pack(side='left', padx=(0, 20))

# Manufacturing process filter
ttk.Label(search_frame, text="Filter Manufacturing Process:", font=('Segoe UI', 11)).pack(side='left')
mfg_process_var = tk.StringVar()
mfg_process_options = ["All"] + sorted(df['Manufacturing process'].dropna().unique().tolist())
mfg_process_combobox = ttk.Combobox(search_frame, textvariable=mfg_process_var, values=mfg_process_options, state='readonly', width=25, font=('Segoe UI', 10))
mfg_process_combobox.set("All")
mfg_process_combobox.pack(side='left', padx=(0, 20))

# Applications filter
ttk.Label(search_frame, text="Filter Applications:", font=('Segoe UI', 11)).pack(side='left')
applications_var = tk.StringVar()
applications_options = ["All"] + sorted(df['Applications'].dropna().unique().tolist())
applications_combobox = ttk.Combobox(search_frame, textvariable=applications_var, values=applications_options, state='readonly', width=25, font=('Segoe UI', 10))
applications_combobox.set("All")
applications_combobox.pack(side='left')

# --- New Material Type Buttons Frame ---
material_type_frame = ttk.Frame(main_frame)
material_type_frame.pack(fill='x', pady=(0, 10))

ttk.Label(material_type_frame, text="Filter by Material Type:", font=('Segoe UI', 11, 'bold')).pack(side='left', padx=(0, 10))

# This will hold the currently active material type filter
material_type_filter = tk.StringVar(value="")  # empty means no filter

# Define your material types to filter on (adjust as needed)
material_types = ["Steel", "Cast Iron", "Aluminum"]

def material_type_button_clicked(mat_type):
    current = material_type_filter.get()
    if current == mat_type:
        # Toggle off if clicking same button again
        material_type_filter.set("")
    else:
        material_type_filter.set(mat_type)
    update_view()

# Create buttons
buttons = []
for mat in material_types:
    b = ttk.Button(material_type_frame, text=mat, width=24, command=lambda m=mat: material_type_button_clicked(m))
    b.pack(side='left', padx=5)
    buttons.append(b)

# Treeview widget (same as before)
tree = ttk.Treeview(main_frame, columns=list(df.columns), show='headings')

# Define headings and column widths
for col in df.columns:
    tree.heading(col, text=col)
    tree.column(col, width=110, anchor='center')

# Scrollbars
vsb = ttk.Scrollbar(main_frame, orient="vertical", command=tree.yview)
hsb = ttk.Scrollbar(main_frame, orient="horizontal", command=tree.xview)
tree.configure(yscrollcommand=vsb.set, xscrollcommand=hsb.set)
vsb.pack(side='right', fill='y')
hsb.pack(side='bottom', fill='x')
tree.pack(fill='both', expand=True)

# Display function
def display_data(dataframe):
    tree.delete(*tree.get_children())
    for i, (_, row) in enumerate(dataframe.iterrows()):
        tag = 'evenrow' if i % 2 == 0 else 'oddrow'
        tree.insert('', 'end', values=list(row), tags=(tag,))
    tree.tag_configure('evenrow', background='white')
    tree.tag_configure('oddrow', background='#e6f2ff')

# Initial load
display_data(df)

# Update function with all filters + material type filter
def update_view(*args):
    filtered_df = df.copy()

    # Filter by Material search
    search_text = search_var.get().strip().lower()
    if search_text != "":
        filtered_df = filtered_df[filtered_df['Material'].str.lower().str.contains(search_text)]

    # Filter by Manufacturing process
    mfg_value = mfg_process_var.get()
    if mfg_value != "All":
        filtered_df = filtered_df[filtered_df['Manufacturing process'] == mfg_value]

    # Filter by Applications
    app_value = applications_var.get()
    if app_value != "All":
        filtered_df = filtered_df[filtered_df['Applications'] == app_value]

    # Filter by Material Type buttons if active
    mat_type = material_type_filter.get()
    if mat_type:
        # Filter by rows where 'Material' column contains the material type text (case insensitive)
        filtered_df = filtered_df[filtered_df['Material'].str.contains(mat_type, case=False, na=False)]

    # Sort if selected
    sort_column = sort_var.get()
    if sort_column in sort_options:
        try:
            filtered_df = filtered_df.sort_values(by=sort_column, ascending=True)
        except Exception as e:
            print(f"Sorting error: {e}")

    display_data(filtered_df)

# Bindings to update view on changes
search_var.trace_add('write', update_view)
sort_combobox.bind('<<ComboboxSelected>>', update_view)
mfg_process_combobox.bind('<<ComboboxSelected>>', update_view)
applications_combobox.bind('<<ComboboxSelected>>', update_view)

root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
import pandas as pd

# Load the Excel data
df = pd.read_excel("sample_material_data.xlsx")

# Create the main window
root = tk.Tk()
root.title("Material Data")
root.geometry("1250x750")
root.configure(bg="#f0f0f0")

# Style configuration
style = ttk.Style(root)
style.theme_use('clam')

style.configure("Treeview",
                background="white",
                foreground="black",
                rowheight=25,
                fieldbackground="white",
                font=('Segoe UI', 10))

style.map('Treeview', background=[('selected', '#347083')], foreground=[('selected', 'white')])

style.configure("Treeview.Heading",
                font=('Segoe UI', 11, 'bold'),
                background="#4a7abc",
                foreground="white")

# Define button styles for material type buttons
style.configure('Material.TButton', background='#f0f0f0', foreground='black')
style.configure('SelectedMaterial.TButton', background='#d3d3d3', foreground='black')

# Frame for Search + Treeview
main_frame = ttk.Frame(root, padding=10)
main_frame.pack(fill='both', expand=True)

# Search and filter frame
search_frame = ttk.Frame(main_frame)
search_frame.pack(fill='x', pady=(0, 10))

# Search by Material
ttk.Label(search_frame, text="Search Material:", font=('Segoe UI', 11)).pack(side='left', padx=(0, 5))
search_var = tk.StringVar()
search_entry = ttk.Entry(search_frame, textvariable=search_var, font=('Segoe UI', 11), width=30)
search_entry.pack(side='left', padx=(0, 20))

# Sorting dropdown
ttk.Label(search_frame, text="Sort by:", font=('Segoe UI', 11)).pack(side='left')
sort_var = tk.StringVar()
sort_options = ["Youngs modulus", "Poissons ratio", "UTS", "Yield strength", "Endurance Strength"]
sort_combobox = ttk.Combobox(search_frame, textvariable=sort_var, values=sort_options, state='readonly', width=25, font=('Segoe UI', 10))
sort_combobox.set("Select a column")
sort_combobox.pack(side='left', padx=(0, 20))

# Manufacturing process filter
ttk.Label(search_frame, text="Filter Manufacturing Process:", font=('Segoe UI', 11)).pack(side='left')
mfg_process_var = tk.StringVar()
mfg_process_options = ["All"] + sorted(df['Manufacturing process'].dropna().unique().tolist())
mfg_process_combobox = ttk.Combobox(search_frame, textvariable=mfg_process_var, values=mfg_process_options, state='readonly', width=25, font=('Segoe UI', 10))
mfg_process_combobox.set("All")
mfg_process_combobox.pack(side='left', padx=(0, 20))

# Applications filter
ttk.Label(search_frame, text="Filter Applications:", font=('Segoe UI', 11)).pack(side='left')
applications_var = tk.StringVar()
applications_options = ["All"] + sorted(df['Applications'].dropna().unique().tolist())
applications_combobox = ttk.Combobox(search_frame, textvariable=applications_var, values=applications_options, state='readonly', width=25, font=('Segoe UI', 10))
applications_combobox.set("All")
applications_combobox.pack(side='left')

# New Material Type Buttons Frame
material_type_frame = ttk.Frame(main_frame)
material_type_frame.pack(fill='x', pady=(0, 10))

ttk.Label(material_type_frame, text="Filter by Material Type:", font=('Segoe UI', 11, 'bold')).pack(side='left', padx=(0, 10))

material_type_filter = tk.StringVar(value="")  # empty means no filter

material_types = ["Steel", "Aluminium", "Plastics"]

selected_button = None  # To keep track of selected button widget

def material_type_button_clicked(mat):
    global selected_button
    current = material_type_filter.get()
    if current == mat:
        # Toggle off
        material_type_filter.set("")
        if selected_button:
            selected_button.configure(style='Material.TButton')
            selected_button = None
    else:
        material_type_filter.set(mat)
        if selected_button:
            selected_button.configure(style='Material.TButton')
        # Find new button to highlight
        for btn in buttons:
            if btn['text'] == mat:
                btn.configure(style='SelectedMaterial.TButton')
                selected_button = btn
                break
    update_view()

# Create buttons with initial style
buttons = []
for mat in material_types:
    b = ttk.Button(material_type_frame, text=mat, width=12, style='Material.TButton',
                   command=lambda m=mat: material_type_button_clicked(m))
    b.pack(side='left', padx=5)
    buttons.append(b)

# Treeview widget
tree = ttk.Treeview(main_frame, columns=list(df.columns), show='headings')

for col in df.columns:
    tree.heading(col, text=col)
    tree.column(col, width=110, anchor='center')

vsb = ttk.Scrollbar(main_frame, orient="vertical", command=tree.yview)
hsb = ttk.Scrollbar(main_frame, orient="horizontal", command=tree.xview)
tree.configure(yscrollcommand=vsb.set, xscrollcommand=hsb.set)
vsb.pack(side='right', fill='y')
hsb.pack(side='bottom', fill='x')
tree.pack(fill='both', expand=True)

def display_data(dataframe):
    tree.delete(*tree.get_children())
    for i, (_, row) in enumerate(dataframe.iterrows()):
        tag = 'evenrow' if i % 2 == 0 else 'oddrow'
        tree.insert('', 'end', values=list(row), tags=(tag,))
    tree.tag_configure('evenrow', background='white')
    tree.tag_configure('oddrow', background='#e6f2ff')

display_data(df)

def update_view(*args):
    filtered_df = df.copy()

    # Material search filter
    search_text = search_var.get().strip().lower()
    if search_text != "":
        filtered_df = filtered_df[filtered_df['Material'].str.lower().str.contains(search_text)]

    # Manufacturing process filter
    mfg_value = mfg_process_var.get()
    if mfg_value != "All":
        filtered_df = filtered_df[filtered_df['Manufacturing process'] == mfg_value]

    # Applications filter
    app_value = applications_var.get()
    if app_value != "All":
        filtered_df = filtered_df[filtered_df['Applications'] == app_value]

    # Material type button filter
    mat_type = material_type_filter.get()
    if mat_type:
        filtered_df = filtered_df[filtered_df['Material'].str.contains(mat_type, case=False, na=False)]

    # Sorting
    sort_column = sort_var.get()
    if sort_column in sort_options:
        try:
            filtered_df = filtered_df.sort_values(by=sort_column, ascending=True)
        except Exception as e:
            print(f"Sorting error: {e}")

    display_data(filtered_df)

search_var.trace_add('write', update_view)
sort_combobox.bind('<<ComboboxSelected>>', update_view)
mfg_process_combobox.bind('<<ComboboxSelected>>', update_view)
applications_combobox.bind('<<ComboboxSelected>>', update_view)

root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
import pandas as pd

# Load the Excel data
df = pd.read_excel("sample_material_data.xlsx")

# Create the main window
root = tk.Tk()
root.title("Material Data")
root.geometry("1250x750")
root.configure(bg="#f0f0f0")

# Style configuration
style = ttk.Style(root)
style.theme_use('clam')

style.configure("Treeview",
                background="white",
                foreground="black",
                rowheight=25,
                fieldbackground="white",
                font=('Segoe UI', 10))

style.map('Treeview', background=[('selected', '#347083')], foreground=[('selected', 'white')])

style.configure("Treeview.Heading",
                font=('Segoe UI', 11, 'bold'),
                background="#4a7abc",
                foreground="white")

# Define button styles for material type buttons
style.configure('Material.TButton', background='#f0f0f0', foreground='black')
style.configure('SelectedMaterial.TButton', background='#87ceeb', foreground='black')

# Frame for Search + Treeview
main_frame = ttk.Frame(root, padding=10)
main_frame.pack(fill='both', expand=True)

# Search and filter frame
search_frame = ttk.Frame(main_frame)
search_frame.pack(fill='x', pady=(0, 10))

# Search by Material
ttk.Label(search_frame, text="Search Material:", font=('Segoe UI', 11)).pack(side='left', padx=(0, 5))
search_var = tk.StringVar()
search_entry = ttk.Entry(search_frame, textvariable=search_var, font=('Segoe UI', 11), width=30)
search_entry.pack(side='left', padx=(0, 20))

# Sorting dropdown
ttk.Label(search_frame, text="Sort by:", font=('Segoe UI', 11)).pack(side='left')
sort_var = tk.StringVar()
sort_options = ["Youngs modulus", "Poissons ratio", "UTS", "Yield strength", "Endurance Strength"]
sort_combobox = ttk.Combobox(search_frame, textvariable=sort_var, values=sort_options, state='readonly', width=25, font=('Segoe UI', 10))
sort_combobox.set("Select a column")
sort_combobox.pack(side='left', padx=(0, 20))

# Manufacturing process filter
ttk.Label(search_frame, text="Filter Manufacturing Process:", font=('Segoe UI', 11)).pack(side='left')
mfg_process_var = tk.StringVar()
mfg_process_options = ["All"] + sorted(df['Manufacturing process'].dropna().unique().tolist())
mfg_process_combobox = ttk.Combobox(search_frame, textvariable=mfg_process_var, values=mfg_process_options, state='readonly', width=25, font=('Segoe UI', 10))
mfg_process_combobox.set("All")
mfg_process_combobox.pack(side='left', padx=(0, 20))

# Applications filter
ttk.Label(search_frame, text="Filter Applications:", font=('Segoe UI', 11)).pack(side='left')
applications_var = tk.StringVar()
applications_options = ["All"] + sorted(df['Applications'].dropna().unique().tolist())
applications_combobox = ttk.Combobox(search_frame, textvariable=applications_var, values=applications_options, state='readonly', width=25, font=('Segoe UI', 10))
applications_combobox.set("All")
applications_combobox.pack(side='left')

# Treeview widget and scrollbars
tree = ttk.Treeview(main_frame, columns=list(df.columns), show='headings')

for col in df.columns:
    tree.heading(col, text=col)
    tree.column(col, width=110, anchor='center')

vsb = ttk.Scrollbar(main_frame, orient="vertical", command=tree.yview)
hsb = ttk.Scrollbar(main_frame, orient="horizontal", command=tree.xview)
tree.configure(yscrollcommand=vsb.set, xscrollcommand=hsb.set)

vsb.pack(side='right', fill='y')
tree.pack(fill='both', expand=True)

# Material Type Buttons Frame placed here ABOVE horizontal scrollbar
material_type_frame = ttk.Frame(main_frame)
material_type_frame.pack(fill='x', pady=(10, 5))

ttk.Label(material_type_frame, text="Filter by Material Type:", font=('Segoe UI', 11, 'bold')).pack(side='left', padx=(0, 10))

material_type_filter = tk.StringVar(value="")  # empty means no filter

material_types = ["Steel", "Aluminum", "Cast Iron"]

selected_button = None  # To keep track of selected button widget

def material_type_button_clicked(mat):
    global selected_button
    current = material_type_filter.get()
    if current == mat:
        material_type_filter.set("")
        if selected_button:
            selected_button.configure(style='Material.TButton')
            selected_button = None
    else:
        material_type_filter.set(mat)
        if selected_button:
            selected_button.configure(style='Material.TButton')
        for btn in buttons:
            if btn['text'] == mat:
                btn.configure(style='SelectedMaterial.TButton')
                selected_button = btn
                break
    update_view()

buttons = []
for mat in material_types:
    b = ttk.Button(material_type_frame, text=mat, width=12, style='Material.TButton',
                   command=lambda m=mat: material_type_button_clicked(m))
    b.pack(side='left', padx=5)
    buttons.append(b)

hsb.pack(side='bottom', fill='x')

def display_data(dataframe):
    tree.delete(*tree.get_children())
    for i, (_, row) in enumerate(dataframe.iterrows()):
        tag = 'evenrow' if i % 2 == 0 else 'oddrow'
        tree.insert('', 'end', values=list(row), tags=(tag,))
    tree.tag_configure('evenrow', background='white')
    tree.tag_configure('oddrow', background='#e6f2ff')

display_data(df)

def update_view(*args):
    filtered_df = df.copy()

    # Material search filter
    search_text = search_var.get().strip().lower()
    if search_text != "":
        filtered_df = filtered_df[filtered_df['Material'].str.lower().str.contains(search_text)]

    # Manufacturing process filter
    mfg_value = mfg_process_var.get()
    if mfg_value != "All":
        filtered_df = filtered_df[filtered_df['Manufacturing process'] == mfg_value]

    # Applications filter
    app_value = applications_var.get()
    if app_value != "All":
        filtered_df = filtered_df[filtered_df['Applications'] == app_value]

    # Material type button filter
    mat_type = material_type_filter.get()
    if mat_type:
        filtered_df = filtered_df[filtered_df['Material'].str.contains(mat_type, case=False, na=False)]

    # Sorting
    sort_column = sort_var.get()
    if sort_column in sort_options:
        try:
            filtered_df = filtered_df.sort_values(by=sort_column, ascending=True)
        except Exception as e:
            print(f"Sorting error: {e}")

    display_data(filtered_df)

search_var.trace_add('write', update_view)
sort_combobox.bind('<<ComboboxSelected>>', update_view)
mfg_process_combobox.bind('<<ComboboxSelected>>', update_view)
applications_combobox.bind('<<ComboboxSelected>>', update_view)

root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
import pandas as pd

# Load the Excel data
df = pd.read_excel("sample_material_data.xlsx")

# Create the main window
root = tk.Tk()
root.title("Material Data")
root.geometry("1250x750")
root.configure(bg="#f0f0f0")

# Style configuration
style = ttk.Style(root)
style.theme_use('clam')

style.configure(
    "Treeview",
    background="white",
    foreground="black",
    rowheight=25,
    fieldbackground="white",
    font=('Segoe UI', 10)
)

style.map(
    'Treeview',
    background=[('selected', '#347083')],
    foreground=[('selected', 'white')]
)

style.configure(
    "Treeview.Heading",
    font=('Segoe UI', 11, 'bold'),
    background="#4a7abc",
    foreground="white"
)

# Button styles for material type toggling
style.configure('Material.TButton', background='#f0f0f0', foreground='black')
style.configure('SelectedMaterial.TButton', background='#87ceeb', foreground='black')

# --------- Main Frame Setup ---------
main_frame = ttk.Frame(root, padding=10)
main_frame.pack(fill='both', expand=True)

# --------- Search & Filter Frame ---------
search_frame = ttk.Frame(main_frame)
search_frame.pack(fill='x', pady=(0, 10))

# Search by Material
ttk.Label(search_frame, text="Search Material:", font=('Segoe UI', 11)).pack(side='left', padx=(0, 5))

search_var = tk.StringVar()
search_entry = ttk.Entry(search_frame, textvariable=search_var, font=('Segoe UI', 11), width=30)
search_entry.pack(side='left', padx=(0, 20))

# Sorting dropdown
ttk.Label(search_frame, text="Sort by:", font=('Segoe UI', 11)).pack(side='left')

sort_var = tk.StringVar()
sort_options = ["None","Youngs modulus", "Poissons ratio", "UTS", "Yield strength", "Endurance Strength"]

sort_combobox = ttk.Combobox(
    search_frame,
    textvariable=sort_var,
    values=sort_options,
    state='readonly',
    width=25,
    font=('Segoe UI', 10)
)
sort_combobox.set("Select a column")
sort_combobox.pack(side='left', padx=(0, 20))

# Manufacturing Process Filter
ttk.Label(search_frame, text="Filter Manufacturing Process:", font=('Segoe UI', 11)).pack(side='left')

mfg_process_var = tk.StringVar()
mfg_process_options = ["All"] + sorted(df['Manufacturing process'].dropna().unique().tolist())

mfg_process_combobox = ttk.Combobox(
    search_frame,
    textvariable=mfg_process_var,
    values=mfg_process_options,
    state='readonly',
    width=25,
    font=('Segoe UI', 10)
)
mfg_process_combobox.set("All")
mfg_process_combobox.pack(side='left', padx=(0, 20))

# Applications Filter
ttk.Label(search_frame, text="Filter Applications:", font=('Segoe UI', 11)).pack(side='left')

applications_var = tk.StringVar()
applications_options = ["All"] + sorted(df['Applications'].dropna().unique().tolist())

applications_combobox = ttk.Combobox(
    search_frame,
    textvariable=applications_var,
    values=applications_options,
    state='readonly',
    width=25,
    font=('Segoe UI', 10)
)
applications_combobox.set("All")
applications_combobox.pack(side='left')

# --------- Treeview Widget Setup ---------
tree = ttk.Treeview(main_frame, columns=list(df.columns), show='headings')

for col in df.columns:
    tree.heading(col, text=col)
    tree.column(col, width=110, anchor='center')

vsb = ttk.Scrollbar(main_frame, orient="vertical", command=tree.yview)
hsb = ttk.Scrollbar(main_frame, orient="horizontal", command=tree.xview)

tree.configure(yscrollcommand=vsb.set, xscrollcommand=hsb.set)

vsb.pack(side='right', fill='y')
tree.pack(fill='both', expand=True)

# --------- Material Type Buttons Frame (Above horizontal scrollbar) ---------
material_type_frame = ttk.Frame(main_frame)
material_type_frame.pack(fill='x', pady=(10, 5))

ttk.Label(material_type_frame, text="Filter by Material Type:", font=('Segoe UI', 11, 'bold')).pack(side='left', padx=(0, 10))

material_type_filter = tk.StringVar(value="")  # No filter initially

material_types = ["Steel", "Aluminum", "Cast Iron"]
selected_button = None  # To track which button is selected


def material_type_button_clicked(mat):
    global selected_button
    current = material_type_filter.get()

    if current == mat:
        # Deselect if same button clicked again
        material_type_filter.set("")
        if selected_button:
            selected_button.configure(style='Material.TButton')
            selected_button = None
    else:
        # Select new button and update styles
        material_type_filter.set(mat)

        if selected_button:
            selected_button.configure(style='Material.TButton')

        for btn in buttons:
            if btn['text'] == mat:
                btn.configure(style='SelectedMaterial.TButton')
                selected_button = btn
                break

    update_view()


buttons = []
for mat in material_types:
    btn = ttk.Button(
        material_type_frame,
        text=mat,
        width=12,
        style='Material.TButton',
        command=lambda m=mat: material_type_button_clicked(m)
    )
    btn.pack(side='left', padx=5)
    buttons.append(btn)

hsb.pack(side='bottom', fill='x')  # Horizontal scrollbar at bottom

# --------- Function to Display Data in Treeview ---------
def display_data(dataframe):
    tree.delete(*tree.get_children())
    for i, (_, row) in enumerate(dataframe.iterrows()):
        tag = 'evenrow' if i % 2 == 0 else 'oddrow'
        tree.insert('', 'end', values=list(row), tags=(tag,))
    tree.tag_configure('evenrow', background='white')
    tree.tag_configure('oddrow', background='#e6f2ff')


# Initial load of all data
display_data(df)


# --------- Update View on Filters/Search/Sort ---------
def update_view(*args):
    filtered_df = df.copy()

    # Filter by Material search text
    search_text = search_var.get().strip().lower()
    if search_text:
        filtered_df = filtered_df[filtered_df['Material'].str.lower().str.contains(search_text)]

    # Filter Manufacturing Process
    mfg_value = mfg_process_var.get()
    if mfg_value != "All":
        filtered_df = filtered_df[filtered_df['Manufacturing process'] == mfg_value]

    # Filter Applications
    app_value = applications_var.get()
    if app_value != "All":
        filtered_df = filtered_df[filtered_df['Applications'] == app_value]

    # Filter Material Type from buttons
    mat_type = material_type_filter.get()
    if mat_type:
        filtered_df = filtered_df[filtered_df['Material'].str.contains(mat_type, case=False, na=False)]

    # Sort data if valid column selected
    sort_column = sort_var.get()
    if sort_column and sort_column in sort_options and sort_column != "None":
        try:
            filtered_df = filtered_df.sort_values(by=sort_column, ascending=True)
        except Exception as e:
            print(f"Sorting error: {e}")

    display_data(filtered_df)


# Bind events to trigger filtering and sorting
search_var.trace_add('write', update_view)
sort_combobox.bind('<<ComboboxSelected>>', update_view)
mfg_process_combobox.bind('<<ComboboxSelected>>', update_view)
applications_combobox.bind('<<ComboboxSelected>>', update_view)

root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk, messagebox
import pandas as pd

# Load the Excel data
try:
    df = pd.read_excel("sample_material_data.xlsx")
except FileNotFoundError:
    messagebox.showerror("Error", "sample_material_data.xlsx not found. Please make sure the file is in the same directory.")
    exit()

# Create the main window
root = tk.Tk()
root.title("Material Data")
root.geometry("1250x750")
root.configure(bg="#f0f0f0")

# Style configuration
style = ttk.Style(root)
style.theme_use('clam')

style.configure(
    "Treeview",
    background="white",
    foreground="black",
    rowheight=25,
    fieldbackground="white",
    font=('Segoe UI', 10)
)

style.map(
    'Treeview',
    background=[('selected', '#347083')],
    foreground=[('selected', 'white')]
)

style.configure(
    "Treeview.Heading",
    font=('Segoe UI', 11, 'bold'),
    background="#4a7abc",
    foreground="white"
)

# Button styles for material type toggling
style.configure('Material.TButton', background='#f0f0f0', foreground='black')
style.configure('SelectedMaterial.TButton', background='#87ceeb', foreground='black')

# Add Data Button Style
style.configure('AddData.TButton', background='#28a745', foreground='white', font=('Segoe UI', 10, 'bold'))
style.map('AddData.TButton', background=[('active', '#218838')])


# --------- Main Frame Setup ---------
main_frame = ttk.Frame(root, padding=10)
main_frame.pack(fill='both', expand=True)

# --------- Search & Filter Frame ---------
search_frame = ttk.Frame(main_frame)
search_frame.pack(fill='x', pady=(0, 10))

# Search by Material
ttk.Label(search_frame, text="Search Material:", font=('Segoe UI', 11)).pack(side='left', padx=(0, 5))

search_var = tk.StringVar()
search_entry = ttk.Entry(search_frame, textvariable=search_var, font=('Segoe UI', 11), width=30)
search_entry.pack(side='left', padx=(0, 20))

# Sorting dropdown
ttk.Label(search_frame, text="Sort by:", font=('Segoe UI', 11)).pack(side='left')

sort_var = tk.StringVar()
sort_options = ["None", "Youngs modulus", "Poissons ratio", "UTS", "Yield strength", "Endurance Strength"]

sort_combobox = ttk.Combobox(
    search_frame,
    textvariable=sort_var,
    values=sort_options,
    state='readonly',
    width=25,
    font=('Segoe UI', 10)
)
sort_combobox.set("Select a column")
sort_combobox.pack(side='left', padx=(0, 20))

# Manufacturing Process Filter
ttk.Label(search_frame, text="Filter Manufacturing Process:", font=('Segoe UI', 11)).pack(side='left')

mfg_process_var = tk.StringVar()
mfg_process_options = ["All"] + sorted(df['Manufacturing process'].dropna().unique().tolist())

mfg_process_combobox = ttk.Combobox(
    search_frame,
    textvariable=mfg_process_var,
    values=mfg_process_options,
    state='readonly',
    width=25,
    font=('Segoe UI', 10)
)
mfg_process_combobox.set("All")
mfg_process_combobox.pack(side='left', padx=(0, 20))

# Applications Filter
ttk.Label(search_frame, text="Filter Applications:", font=('Segoe UI', 11)).pack(side='left')

applications_var = tk.StringVar()
applications_options = ["All"] + sorted(df['Applications'].dropna().unique().tolist())

applications_combobox = ttk.Combobox(
    search_frame,
    textvariable=applications_var,
    values=applications_options,
    state='readonly',
    width=25,
    font=('Segoe UI', 10)
)
applications_combobox.set("All")
applications_combobox.pack(side='left')

# --------- Treeview Widget Setup ---------
tree = ttk.Treeview(main_frame, columns=list(df.columns), show='headings')

for col in df.columns:
    tree.heading(col, text=col)
    tree.column(col, width=110, anchor='center')

vsb = ttk.Scrollbar(main_frame, orient="vertical", command=tree.yview)
hsb = ttk.Scrollbar(main_frame, orient="horizontal", command=tree.xview)

tree.configure(yscrollcommand=vsb.set, xscrollcommand=hsb.set)

vsb.pack(side='right', fill='y')
tree.pack(fill='both', expand=True)

# --------- Material Type Buttons Frame (Above horizontal scrollbar) ---------
material_type_frame = ttk.Frame(main_frame)
material_type_frame.pack(fill='x', pady=(10, 5))

ttk.Label(material_type_frame, text="Filter by Material Type:", font=('Segoe UI', 11, 'bold')).pack(side='left', padx=(0, 10))

material_type_filter = tk.StringVar(value="")  # No filter initially

material_types = ["Steel", "Aluminum", "Cast Iron"]
selected_button = None  # To track which button is selected


def material_type_button_clicked(mat):
    global selected_button
    current = material_type_filter.get()

    if current == mat:
        # Deselect if same button clicked again
        material_type_filter.set("")
        if selected_button:
            selected_button.configure(style='Material.TButton')
            selected_button = None
    else:
        # Select new button and update styles
        material_type_filter.set(mat)

        if selected_button:
            selected_button.configure(style='Material.TButton')

        for btn in buttons:
            if btn['text'] == mat:
                btn.configure(style='SelectedMaterial.TButton')
                selected_button = btn
                break

    update_view()


buttons = []
for mat in material_types:
    btn = ttk.Button(
        material_type_frame,
        text=mat,
        width=12,
        style='Material.TButton',
        command=lambda m=mat: material_type_button_clicked(m)
    )
    btn.pack(side='left', padx=5)
    buttons.append(btn)

hsb.pack(side='bottom', fill='x')  # Horizontal scrollbar at bottom

# --------- Function to Display Data in Treeview ---------
def display_data(dataframe):
    tree.delete(*tree.get_children())
    for i, (_, row) in enumerate(dataframe.iterrows()):
        tag = 'evenrow' if i % 2 == 0 else 'oddrow'
        tree.insert('', 'end', values=list(row), tags=(tag,))
    tree.tag_configure('evenrow', background='white')
    tree.tag_configure('oddrow', background='#e6f2ff')


# Initial load of all data
display_data(df)


# --------- Update View on Filters/Search/Sort ---------
def update_view(*args):
    global df # Ensure we use the global df

    filtered_df = df.copy()

    # Filter by Material search text
    search_text = search_var.get().strip().lower()
    if search_text:
        filtered_df = filtered_df[filtered_df['Material'].str.lower().str.contains(search_text, na=False)]

    # Filter Manufacturing Process
    mfg_value = mfg_process_var.get()
    if mfg_value != "All":
        filtered_df = filtered_df[filtered_df['Manufacturing process'] == mfg_value]

    # Filter Applications
    app_value = applications_var.get()
    if app_value != "All":
        filtered_df = filtered_df[filtered_df['Applications'] == app_value]

    # Filter Material Type from buttons
    mat_type = material_type_filter.get()
    if mat_type:
        filtered_df = filtered_df[filtered_df['Material'].str.contains(mat_type, case=False, na=False)]

    # Sort data if valid column selected
    sort_column = sort_var.get()
    if sort_column and sort_column in sort_options and sort_column != "None":
        try:
            # Convert to numeric for proper sorting if applicable
            if sort_column in ["Youngs modulus", "Poissons ratio", "UTS", "Yield strength", "Endurance Strength"]:
                filtered_df = filtered_df.copy() # Avoid SettingWithCopyWarning
                filtered_df[sort_column] = pd.to_numeric(filtered_df[sort_column], errors='coerce')
                filtered_df = filtered_df.sort_values(by=sort_column, ascending=True, na_position='last')
            else:
                filtered_df = filtered_df.sort_values(by=sort_column, ascending=True)
        except Exception as e:
            messagebox.showerror("Sorting Error", f"Could not sort by {sort_column}: {e}")

    display_data(filtered_df)


# Bind events to trigger filtering and sorting
search_var.trace_add('write', update_view)
sort_combobox.bind('<<ComboboxSelected>>', update_view)
mfg_process_combobox.bind('<<ComboboxSelected>>', update_view)
applications_combobox.bind('<<ComboboxSelected>>', update_view)


# --------- Add Data Functionality ---------
def add_data():
    add_window = tk.Toplevel(root)
    add_window.title("Add New Material Data")
    add_window.geometry("500x600")
    add_window.transient(root) # Make it appear on top of the main window
    add_window.grab_set() # Disable interaction with the main window

    form_frame = ttk.Frame(add_window, padding=20)
    form_frame.pack(fill='both', expand=True)

    entries = {}
    for i, col in enumerate(df.columns):
        ttk.Label(form_frame, text=f"{col}:", font=('Segoe UI', 10)).grid(row=i, column=0, sticky='w', pady=5, padx=5)
        entry = ttk.Entry(form_frame, width=40, font=('Segoe UI', 10))
        entry.grid(row=i, column=1, sticky='ew', pady=5, padx=5)
        entries[col] = entry

    def submit_new_data():
        global df
        new_row_data = {}
        for col, entry_widget in entries.items():
            value = entry_widget.get().strip()
            # Basic type conversion for numeric columns, handle errors gracefully
            if col in ["Youngs modulus", "Poissons ratio", "UTS", "Yield strength", "Endurance Strength"]:
                try:
                    new_row_data[col] = float(value) if value else None # Convert to float, None if empty
                except ValueError:
                    messagebox.showerror("Input Error", f"Please enter a valid number for '{col}'.")
                    return
            else:
                new_row_data[col] = value if value else None # Store None for empty strings

        # Create a new DataFrame from the new row
        new_row_df = pd.DataFrame([new_row_data])

        # Append the new row to the main DataFrame
        df = pd.concat([df, new_row_df], ignore_index=True)

        # Save the updated DataFrame back to Excel
        try:
            df.to_excel("sample_material_data.xlsx", index=False)
            messagebox.showinfo("Success", "New data added successfully and saved to Excel.")
            update_view() # Refresh the Treeview
            add_window.destroy() # Close the add data window
        except Exception as e:
            messagebox.showerror("Save Error", f"Could not save data to Excel: {e}")

    submit_button = ttk.Button(
        form_frame,
        text="Add Data",
        command=submit_new_data,
        style='AddData.TButton'
    )
    submit_button.grid(row=len(df.columns), column=0, columnspan=2, pady=20)


# --------- Add Data Button to Main Window ---------
add_data_button = ttk.Button(
    search_frame, # Placed in the search_frame for now, adjust as needed
    text="Add Data",
    command=add_data,
    style='AddData.TButton'
)
add_data_button.pack(side='right', padx=(20, 0)) # Pack it to the right

root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk, messagebox, filedialog
import pandas as pd
import os # Import os module for path operations

# Load the Excel data
try:
    df = pd.read_excel("sample_material_data.xlsx")
except FileNotFoundError:
    messagebox.showerror("Error", "sample_material_data.xlsx not found. Please make sure the file is in the same directory.")
    exit()

# Create the main window
root = tk.Tk()
root.title("Material Data")
root.geometry("1250x750")
root.configure(bg="#f0f0f0")

# Style configuration
style = ttk.Style(root)
style.theme_use('clam')

style.configure(
    "Treeview",
    background="white",
    foreground="black",
    rowheight=25,
    fieldbackground="white",
    font=('Segoe UI', 10)
)

style.map(
    'Treeview',
    background=[('selected', '#347083')],
    foreground=[('selected', 'white')]
)

style.configure(
    "Treeview.Heading",
    font=('Segoe UI', 11, 'bold'),
    background="#4a7abc",
    foreground="white"
)

# Button styles for material type toggling
style.configure('Material.TButton', background='#f0f0f0', foreground='black')
style.configure('SelectedMaterial.TButton', background='#87ceeb', foreground='black')

# Add Data Button Style
style.configure('AddData.TButton', background='#28a745', foreground='white', font=('Segoe UI', 10, 'bold'))
style.map('AddData.TButton', background=[('active', '#218838')])

# Download Button Style
style.configure('Download.TButton', background='#007bff', foreground='white', font=('Segoe UI', 10, 'bold'))
style.map('Download.TButton', background=[('active', '#0056b3')])


# --------- Main Frame Setup ---------
main_frame = ttk.Frame(root, padding=10)
main_frame.pack(fill='both', expand=True)

# --------- Search & Filter Frame ---------
search_filter_add_frame = ttk.Frame(main_frame)
search_filter_add_frame.pack(fill='x', pady=(0, 10))

# Search & Filter controls sub-frame (to group them on the left)
search_filter_controls_frame = ttk.Frame(search_filter_add_frame)
search_filter_controls_frame.pack(side='left', fill='x', expand=True)


# Search by Material
ttk.Label(search_filter_controls_frame, text="Search Material:", font=('Segoe UI', 11)).pack(side='left', padx=(0, 5))

search_var = tk.StringVar()
search_entry = ttk.Entry(search_filter_controls_frame, textvariable=search_var, font=('Segoe UI', 11), width=20)
search_entry.pack(side='left', padx=(0, 10))

# Sorting dropdown
ttk.Label(search_filter_controls_frame, text="Sort by:", font=('Segoe UI', 11)).pack(side='left')

sort_var = tk.StringVar()
sort_options = ["None","Youngs modulus", "Poissons ratio", "UTS", "Yield strength", "Endurance Strength"]

sort_combobox = ttk.Combobox(
    search_filter_controls_frame,
    textvariable=sort_var,
    values=sort_options,
    state='readonly',
    width=15,
    font=('Segoe UI', 10)
)
sort_combobox.set("Select a column")
sort_combobox.pack(side='left', padx=(0, 10))

# Manufacturing Process Filter
ttk.Label(search_filter_controls_frame, text="Filter Mfg. Process:", font=('Segoe UI', 11)).pack(side='left')

mfg_process_var = tk.StringVar()
mfg_process_options = ["All"] + sorted(df['Manufacturing process'].dropna().unique().tolist())

mfg_process_combobox = ttk.Combobox(
    search_filter_controls_frame,
    textvariable=mfg_process_var,
    values=mfg_process_options,
    state='readonly',
    width=15,
    font=('Segoe UI', 10)
)
mfg_process_combobox.set("All")
mfg_process_combobox.pack(side='left', padx=(0, 10))

# Applications Filter
ttk.Label(search_filter_controls_frame, text="Filter Applications:", font=('Segoe UI', 11)).pack(side='left')

applications_var = tk.StringVar()
applications_options = ["All"] + sorted(df['Applications'].dropna().unique().tolist())

applications_combobox = ttk.Combobox(
    search_filter_controls_frame,
    textvariable=applications_var,
    values=applications_options,
    state='readonly',
    width=15,
    font=('Segoe UI', 10)
)
applications_combobox.set("All")
applications_combobox.pack(side='left')

# --------- Treeview Widget Setup ---------
tree = ttk.Treeview(main_frame, columns=list(df.columns), show='headings')

for col in df.columns:
    tree.heading(col, text=col)
    tree.column(col, width=110, anchor='center')

vsb = ttk.Scrollbar(main_frame, orient="vertical", command=tree.yview)
hsb = ttk.Scrollbar(main_frame, orient="horizontal", command=tree.xview)

tree.configure(yscrollcommand=vsb.set, xscrollcommand=hsb.set)

vsb.pack(side='right', fill='y')
tree.pack(fill='both', expand=True)

# --------- Material Type Buttons Frame (Above horizontal scrollbar) ---------
material_type_frame = ttk.Frame(main_frame)
material_type_frame.pack(fill='x', pady=(10, 5))

ttk.Label(material_type_frame, text="Filter by Material Type:", font=('Segoe UI', 11, 'bold')).pack(side='left', padx=(0, 10))

material_type_filter = tk.StringVar(value="")  # No filter initially

material_types = ["Steel", "Aluminum", "Cast Iron"]
selected_material_button = None  # To track which button is selected


def material_type_button_clicked(mat):
    global selected_material_button
    current = material_type_filter.get()

    if current == mat:
        # Deselect if same button clicked again
        material_type_filter.set("")
        if selected_material_button:
            selected_material_button.configure(style='Material.TButton')
            selected_material_button = None
    else:
        # Select new button and update styles
        material_type_filter.set(mat)

        if selected_material_button:
            selected_material_button.configure(style='Material.TButton')

        for btn in material_type_buttons:
            if btn['text'] == mat:
                btn.configure(style='SelectedMaterial.TButton')
                selected_material_button = btn
                break

    update_view()


material_type_buttons = []
for mat in material_types:
    btn = ttk.Button(
        material_type_frame,
        text=mat,
        width=12,
        style='Material.TButton',
        command=lambda m=mat: material_type_button_clicked(m)
    )
    btn.pack(side='left', padx=5)
    material_type_buttons.append(btn)

hsb.pack(side='bottom', fill='x')  # Horizontal scrollbar at bottom

# --------- Function to Display Data in Treeview ---------
def display_data(dataframe):
    tree.delete(*tree.get_children())
    for i, (_, row) in enumerate(dataframe.iterrows()):
        tag = 'evenrow' if i % 2 == 0 else 'oddrow'
        tree.insert('', 'end', values=list(row), tags=(tag,))
    tree.tag_configure('evenrow', background='white')
    tree.tag_configure('oddrow', background='#e6f2ff')


# Initial load of all data
display_data(df)


# --------- Update View on Filters/Search/Sort ---------
def update_view(*args):
    global df # Ensure we use the global df

    filtered_df = df.copy()

    # Filter by Material search text
    search_text = search_var.get().strip().lower()
    if search_text:
        filtered_df = filtered_df[filtered_df['Material'].str.lower().str.contains(search_text, na=False)]

    # Filter Manufacturing Process
    mfg_value = mfg_process_var.get()
    if mfg_value != "All":
        filtered_df = filtered_df[filtered_df['Manufacturing process'] == mfg_value]

    # Filter Applications
    app_value = applications_var.get()
    if app_value != "All":
        filtered_df = filtered_df[filtered_df['Applications'] == app_value]

    # Filter Material Type from buttons
    mat_type = material_type_filter.get()
    if mat_type:
        filtered_df = filtered_df[filtered_df['Material'].str.contains(mat_type, case=False, na=False)]

    # Sort data if valid column selected
    sort_column = sort_var.get()
    if sort_column and sort_column in sort_options and sort_column != "None":
        try:
            # Convert to numeric for proper sorting if applicable
            if sort_column in ["Youngs modulus", "Poissons ratio", "UTS", "Yield strength", "Endurance Strength"]:
                # Ensure the column exists before attempting to sort
                if sort_column in filtered_df.columns:
                    filtered_df = filtered_df.copy() # Avoid SettingWithCopyWarning
                    # Use a custom sort key to handle mixed types by coercing to numeric,
                    # placing non-numeric values (NaN after coerce) at the end.
                    filtered_df[sort_column] = pd.to_numeric(filtered_df[sort_column], errors='coerce')
                    filtered_df = filtered_df.sort_values(by=sort_column, ascending=True, na_position='last')
                else:
                    messagebox.showwarning("Column Not Found", f"Sorting column '{sort_column}' not found in current data.")
            else:
                filtered_df = filtered_df.sort_values(by=sort_column, ascending=True)
        except Exception as e:
            messagebox.showerror("Sorting Error", f"Could not sort by {sort_column}: {e}")

    display_data(filtered_df)
    check_download_button_state() # Update download button state after view update


# Bind events to trigger filtering and sorting
search_var.trace_add('write', update_view)
sort_combobox.bind('<<ComboboxSelected>>', update_view)
mfg_process_combobox.bind('<<ComboboxSelected>>', update_view)
applications_combobox.bind('<<ComboboxSelected>>', update_view)


# --------- Add Data Functionality ---------
def add_data():
    add_window = tk.Toplevel(root)
    add_window.title("Add New Material Data")
    add_window.geometry("500x600")
    add_window.transient(root) # Make it appear on top of the main window
    add_window.grab_set() # Disable interaction with the main window

    form_frame = ttk.Frame(add_window, padding=20)
    form_frame.pack(fill='both', expand=True)

    entries = {}
    for i, col in enumerate(df.columns):
        ttk.Label(form_frame, text=f"{col}:", font=('Segoe UI', 10)).grid(row=i, column=0, sticky='w', pady=5, padx=5)
        entry = ttk.Entry(form_frame, width=40, font=('Segoe UI', 10))
        entry.grid(row=i, column=1, sticky='ew', pady=5, padx=5)
        entries[col] = entry

    def submit_new_data():
        global df
        new_row_data = {}
        for col, entry_widget in entries.items():
            value = entry_widget.get().strip()
            # Basic type conversion for numeric columns, handle errors gracefully
            if col in ["Youngs modulus", "Poissons ratio", "UTS", "Yield strength", "Endurance Strength"]:
                try:
                    new_row_data[col] = float(value) if value else None # Convert to float, None if empty
                except ValueError:
                    messagebox.showerror("Input Error", f"Please enter a valid number for '{col}'.")
                    return
            else:
                new_row_data[col] = value if value else None # Store None for empty strings

        # Create a new DataFrame from the new row
        new_row_df = pd.DataFrame([new_row_data])

        # Append the new row to the main DataFrame
        df = pd.concat([df, new_row_df], ignore_index=True)

        # Save the updated DataFrame back to Excel
        try:
            df.to_excel("sample_material_data.xlsx", index=False)
            messagebox.showinfo("Success", "New data added successfully and saved to Excel.")
            update_view() # Refresh the Treeview
            add_window.destroy() # Close the add data window
        except Exception as e:
            messagebox.showerror("Save Error", f"Could not save data to Excel: {e}")

    submit_button = ttk.Button(
        form_frame,
        text="Add Data",
        command=submit_new_data,
        style='AddData.TButton'
    )
    submit_button.grid(row=len(df.columns), column=0, columnspan=2, pady=20)


# --------- Download Data Functionality ---------
def download_selected_row_details():
    selected_item = tree.selection()
    if not selected_item:
        messagebox.showwarning("No Selection", "Please select a row to download details.")
        return

    # Get the values of the selected row
    values = tree.item(selected_item, 'values')
    
    # Create a dictionary of the selected row data using column names
    selected_row_dict = dict(zip(df.columns, values))

    numerical_details = []
    # Define columns considered numerical for download
    numerical_columns = ["Youngs modulus", "Poissons ratio", "UTS", "Yield strength", "Endurance Strength"]

    for col in numerical_columns:
        if col in selected_row_dict and selected_row_dict[col] is not None:
            numerical_details.append(f"{col}: {selected_row_dict[col]}")
    
    if not numerical_details:
        messagebox.showinfo("No Numerical Data", "The selected row does not contain numerical details for download.")
        return

    output_content = f"Material: {selected_row_dict.get('Material', 'N/A')}\n"
    output_content += f"Manufacturing Process: {selected_row_dict.get('Manufacturing process', 'N/A')}\n"
    output_content += f"Applications: {selected_row_dict.get('Applications', 'N/A')}\n\n"
    output_content += "--- Numerical Properties ---\n"
    output_content += "\n".join(numerical_details)

    # Open a file dialog to choose where to save the file
    initial_filename = f"{selected_row_dict.get('Material', 'material')}_numerical_details.txt"
    file_path = filedialog.asksaveasfilename(
        defaultextension=".txt",
        filetypes=[("Text files", "*.txt"), ("All files", "*.*")],
        initialfile=initial_filename
    )

    if file_path:
        try:
            with open(file_path, "w") as f:
                f.write(output_content)
            messagebox.showinfo("Download Complete", f"Numerical details saved to:\n{os.path.basename(file_path)}")
        except Exception as e:
            messagebox.showerror("Download Error", f"Failed to save file: {e}")

# Function to enable/disable download button based on selection
def check_download_button_state(*args):
    if tree.selection():
        download_data_button.config(state='normal')
    else:
        download_data_button.config(state='disabled')

# Bind the Treeview selection event to the state checker
tree.bind('<<TreeviewSelect>>', check_download_button_state)

# --------- Add Data Button to Main Window ---------
add_data_button = ttk.Button(
    search_filter_add_frame, # Placed in the combined search/filter/add frame
    text="Add Data",
    command=add_data,
    style='AddData.TButton'
)
add_data_button.pack(side='right', padx=(10, 5)) # Pack it to the right of controls

# --------- Download Data Button to Main Window ---------
download_data_button = ttk.Button(
    search_filter_add_frame, # Placed in the combined search/filter/add frame
    text="Download Details",
    command=download_selected_row_details,
    style='Download.TButton',
    state='disabled' # Initially disabled until a row is selected
)
download_data_button.pack(side='right', padx=(5, 10))

# Initial check for download button state
check_download_button_state()

root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk, messagebox, filedialog
import pandas as pd
import os # Import os module for path operations
import math # Import math module for log

# Load the Excel data
try:
    df = pd.read_excel("sample_material_data.xlsx")
except FileNotFoundError:
    messagebox.showerror("Error", "sample_material_data.xlsx not found. Please make sure the file is in the same directory.")
    exit()

# Create the main window
root = tk.Tk()
root.title("Material Data")
root.geometry("1250x750")
root.configure(bg="#f0f0f0")

# Style configuration
style = ttk.Style(root)
style.theme_use('clam')

style.configure(
    "Treeview",
    background="white",
    foreground="black",
    rowheight=25,
    fieldbackground="white",
    font=('Segoe UI', 10)
)

style.map(
    'Treeview',
    background=[('selected', '#347083')],
    foreground=[('selected', 'white')]
)

style.configure(
    "Treeview.Heading",
    font=('Segoe UI', 11, 'bold'),
    background="#4a7abc",
    foreground="white"
)

# Button styles for material type toggling
style.configure('Material.TButton', background='#f0f0f0', foreground='black')
style.configure('SelectedMaterial.TButton', background='#87ceeb', foreground='black')

# Add Data Button Style
style.configure('AddData.TButton', background='#28a745', foreground='white', font=('Segoe UI', 10, 'bold'))
style.map('AddData.TButton', background=[('active', '#218838')])

# Download Button Style
style.configure('Download.TButton', background='#007bff', foreground='white', font=('Segoe UI', 10, 'bold'))
style.map('Download.TButton', background=[('active', '#0056b3')])


# --------- Main Frame Setup ---------
main_frame = ttk.Frame(root, padding=10)
main_frame.pack(fill='both', expand=True)

# --------- Search & Filter Frame ---------
search_filter_add_frame = ttk.Frame(main_frame)
search_filter_add_frame.pack(fill='x', pady=(0, 10))

# Search & Filter controls sub-frame (to group them on the left)
search_filter_controls_frame = ttk.Frame(search_filter_add_frame)
search_filter_controls_frame.pack(side='left', fill='x', expand=True)


# Search by Material
ttk.Label(search_filter_controls_frame, text="Search Material:", font=('Segoe UI', 11)).pack(side='left', padx=(0, 5))

search_var = tk.StringVar()
search_entry = ttk.Entry(search_filter_controls_frame, textvariable=search_var, font=('Segoe UI', 11), width=20)
search_entry.pack(side='left', padx=(0, 10))

# Sorting dropdown
ttk.Label(search_filter_controls_frame, text="Sort by:", font=('Segoe UI', 11)).pack(side='left')

sort_var = tk.StringVar()
sort_options = ["None","Youngs modulus", "Poissons ratio", "UTS", "Yield strength", "Endurance Strength"]

sort_combobox = ttk.Combobox(
    search_filter_controls_frame,
    textvariable=sort_var,
    values=sort_options,
    state='readonly',
    width=15,
    font=('Segoe UI', 10)
)
sort_combobox.set("Select a column")
sort_combobox.pack(side='left', padx=(0, 10))

# Manufacturing Process Filter
ttk.Label(search_filter_controls_frame, text="Filter Mfg. Process:", font=('Segoe UI', 11)).pack(side='left')

mfg_process_var = tk.StringVar()
mfg_process_options = ["All"] + sorted(df['Manufacturing process'].dropna().unique().tolist())

mfg_process_combobox = ttk.Combobox(
    search_filter_controls_frame,
    textvariable=mfg_process_var,
    values=mfg_process_options,
    state='readonly',
    width=15,
    font=('Segoe UI', 10)
)
mfg_process_combobox.set("All")
mfg_process_combobox.pack(side='left', padx=(0, 10))

# Applications Filter
ttk.Label(search_filter_controls_frame, text="Filter Applications:", font=('Segoe UI', 11)).pack(side='left')

applications_var = tk.StringVar()
applications_options = ["All"] + sorted(df['Applications'].dropna().unique().tolist())

applications_combobox = ttk.Combobox(
    search_filter_controls_frame,
    textvariable=applications_var,
    values=applications_options,
    state='readonly',
    width=15,
    font=('Segoe UI', 10)
)
applications_combobox.set("All")
applications_combobox.pack(side='left')

# --------- Treeview Widget Setup ---------
tree = ttk.Treeview(main_frame, columns=list(df.columns), show='headings')

for col in df.columns:
    tree.heading(col, text=col)
    tree.column(col, width=110, anchor='center')

vsb = ttk.Scrollbar(main_frame, orient="vertical", command=tree.yview)
hsb = ttk.Scrollbar(main_frame, orient="horizontal", command=tree.xview)

tree.configure(yscrollcommand=vsb.set, xscrollcommand=hsb.set)

vsb.pack(side='right', fill='y')
tree.pack(fill='both', expand=True)

# --------- Material Type Buttons Frame (Above horizontal scrollbar) ---------
material_type_frame = ttk.Frame(main_frame)
material_type_frame.pack(fill='x', pady=(10, 5))

ttk.Label(material_type_frame, text="Filter by Material Type:", font=('Segoe UI', 11, 'bold')).pack(side='left', padx=(0, 10))

material_type_filter = tk.StringVar(value="")  # No filter initially

material_types = ["Steel", "Aluminum", "Cast Iron"]
selected_material_button = None  # To track which button is selected


def material_type_button_clicked(mat):
    global selected_material_button
    current = material_type_filter.get()

    if current == mat:
        # Deselect if same button clicked again
        material_type_filter.set("")
        if selected_material_button:
            selected_material_button.configure(style='Material.TButton')
            selected_material_button = None
    else:
        # Select new button and update styles
        material_type_filter.set(mat)

        if selected_material_button:
            selected_material_button.configure(style='Material.TButton')

        for btn in material_type_buttons:
            if btn['text'] == mat:
                btn.configure(style='SelectedMaterial.TButton')
                selected_material_button = btn
                break

    update_view()


material_type_buttons = []
for mat in material_types:
    btn = ttk.Button(
        material_type_frame,
        text=mat,
        width=12,
        style='Material.TButton',
        command=lambda m=mat: material_type_button_clicked(m)
    )
    btn.pack(side='left', padx=5)
    material_type_buttons.append(btn)

hsb.pack(side='bottom', fill='x')  # Horizontal scrollbar at bottom

# --------- Function to Display Data in Treeview ---------
def display_data(dataframe):
    tree.delete(*tree.get_children())
    for i, (_, row) in enumerate(dataframe.iterrows()):
        tag = 'evenrow' if i % 2 == 0 else 'oddrow'
        tree.insert('', 'end', values=list(row), tags=(tag,))
    tree.tag_configure('evenrow', background='white')
    tree.tag_configure('oddrow', background='#e6f2ff')


# Initial load of all data
display_data(df)


# --------- Update View on Filters/Search/Sort ---------
def update_view(*args):
    global df # Ensure we use the global df

    filtered_df = df.copy()

    # Filter by Material search text
    search_text = search_var.get().strip().lower()
    if search_text:
        filtered_df = filtered_df[filtered_df['Material'].str.lower().str.contains(search_text, na=False)]

    # Filter Manufacturing Process
    mfg_value = mfg_process_var.get()
    if mfg_value != "All":
        filtered_df = filtered_df[filtered_df['Manufacturing process'] == mfg_value]

    # Filter Applications
    app_value = applications_var.get()
    if app_value != "All":
        filtered_df = filtered_df[filtered_df['Applications'] == app_value]

    # Filter Material Type from buttons
    mat_type = material_type_filter.get()
    if mat_type:
        filtered_df = filtered_df[filtered_df['Material'].str.contains(mat_type, case=False, na=False)]

    # Sort data if valid column selected
    sort_column = sort_var.get()
    if sort_column and sort_column in sort_options and sort_column != "None":
        try:
            # Convert to numeric for proper sorting if applicable
            if sort_column in ["Youngs modulus", "Poissons ratio", "UTS", "Yield strength", "Endurance Strength"]:
                # Ensure the column exists before attempting to sort
                if sort_column in filtered_df.columns:
                    filtered_df = filtered_df.copy() # Avoid SettingWithCopyWarning
                    # Use a custom sort key to handle mixed types by coercing to numeric,
                    # placing non-numeric values (NaN after coerce) at the end.
                    filtered_df[sort_column] = pd.to_numeric(filtered_df[sort_column], errors='coerce')
                    filtered_df = filtered_df.sort_values(by=sort_column, ascending=True, na_position='last')
                else:
                    messagebox.showwarning("Column Not Found", f"Sorting column '{sort_column}' not found in current data.")
            else:
                filtered_df = filtered_df.sort_values(by=sort_column, ascending=True)
        except Exception as e:
            messagebox.showerror("Sorting Error", f"Could not sort by {sort_column}: {e}")

    display_data(filtered_df)
    check_download_button_state() # Update download button state after view update


# Bind events to trigger filtering and sorting
search_var.trace_add('write', update_view)
sort_combobox.bind('<<ComboboxSelected>>', update_view)
mfg_process_combobox.bind('<<ComboboxSelected>>', update_view)
applications_combobox.bind('<<ComboboxSelected>>', update_view)


# --------- Add Data Functionality ---------
def add_data():
    add_window = tk.Toplevel(root)
    add_window.title("Add New Material Data")
    add_window.geometry("500x600")
    add_window.transient(root) # Make it appear on top of the main window
    add_window.grab_set() # Disable interaction with the main window

    form_frame = ttk.Frame(add_window, padding=20)
    form_frame.pack(fill='both', expand=True)

    entries = {}
    for i, col in enumerate(df.columns):
        ttk.Label(form_frame, text=f"{col}:", font=('Segoe UI', 10)).grid(row=i, column=0, sticky='w', pady=5, padx=5)
        entry = ttk.Entry(form_frame, width=40, font=('Segoe UI', 10))
        entry.grid(row=i, column=1, sticky='ew', pady=5, padx=5)
        entries[col] = entry

    def submit_new_data():
        global df
        new_row_data = {}
        for col, entry_widget in entries.items():
            value = entry_widget.get().strip()
            # Basic type conversion for numeric columns, handle errors gracefully
            if col in ["Youngs modulus", "Poissons ratio", "UTS", "Yield strength", "Endurance Strength", "%elongation"]:
                try:
                    new_row_data[col] = float(value) if value else None # Convert to float, None if empty
                except ValueError:
                    messagebox.showerror("Input Error", f"Please enter a valid number for '{col}'.")
                    return
            else:
                new_row_data[col] = value if value else None # Store None for empty strings

        # Create a new DataFrame from the new row
        new_row_df = pd.DataFrame([new_row_data])

        # Append the new row to the main DataFrame
        df = pd.concat([df, new_row_df], ignore_index=True)

        # Save the updated DataFrame back to Excel
        try:
            df.to_excel("sample_material_data.xlsx", index=False)
            messagebox.showinfo("Success", "New data added successfully and saved to Excel.")
            update_view() # Refresh the Treeview
            add_window.destroy() # Close the add data window
        except Exception as e:
            messagebox.showerror("Save Error", f"Could not save data to Excel: {e}")

    submit_button = ttk.Button(
        form_frame,
        text="Add Data",
        command=submit_new_data,
        style='AddData.TButton'
    )
    submit_button.grid(row=len(df.columns), column=0, columnspan=2, pady=20)


# --------- Download Data Functionality ---------
def download_selected_row_details():
    selected_item = tree.selection()
    if not selected_item:
        messagebox.showwarning("No Selection", "Please select a row to download details.")
        return

    # Get the values of the selected row
    values = tree.item(selected_item, 'values')
    
    # Create a dictionary of the selected row data using column names
    selected_row_dict = dict(zip(df.columns, values))

    # --- Extract required properties ---
    material_name = selected_row_dict.get('Material', 'N/A')
    mfg_process = selected_row_dict.get('Manufacturing process', 'N/A')
    applications = selected_row_dict.get('Applications', 'N/A')

    # Convert extracted values to float, handling potential missing or non-numeric data
    try:
        yield_strength = float(selected_row_dict.get('Yield strength')) if selected_row_dict.get('Yield strength') is not None else None
        uts = float(selected_row_dict.get('UTS')) if selected_row_dict.get('UTS') is not None else None
        percent_elongation = float(selected_row_dict.get('%elongation')) if selected_row_dict.get('%elongation') is not None else None
        youngs_modulus = float(selected_row_dict.get('Youngs modulus')) if selected_row_dict.get('Youngs modulus') is not None else None
    except ValueError:
        messagebox.showerror("Data Error", "Could not convert one or more required properties to numbers. Please check the data in the Excel file.")
        return

    # --- Perform Calculations ---
    calculated_values = []
    calculation_errors = []

    # 1) Nominal strain at yield = yield strength / young's modulus
    if yield_strength is not None and youngs_modulus is not None and youngs_modulus != 0:
        nominal_strain_at_yield = yield_strength / youngs_modulus
        calculated_values.append(f"Nominal strain at yield: {nominal_strain_at_yield:.8f}")
    else:
        nominal_strain_at_yield = None
        calculation_errors.append("Nominal strain at yield: Missing Yield Strength or Young's Modulus or Young's Modulus is zero.")

    # 2) Nominal strain at UTS = %elongation/100
    if percent_elongation is not None:
        nominal_strain_at_uts = percent_elongation / 100.0
        calculated_values.append(f"Nominal strain at UTS: {nominal_strain_at_uts:.8f}")
    else:
        nominal_strain_at_uts = None
        calculation_errors.append("Nominal strain at UTS: Missing %elongation.")

    # 3) At yield engineering strain = Nominal strain at yield
    at_yield_engg_strain = nominal_strain_at_yield
    if at_yield_engg_strain is not None:
        calculated_values.append(f"At yield engineering strain: {at_yield_engg_strain:.8f}")
    else:
        calculated_values.append("At yield engineering strain: Not calculable (see above).")

    # 4) At yield true strain = log base e (1+at yield engineering strain)
    if at_yield_engg_strain is not None and (1 + at_yield_engg_strain) > 0:
        at_yield_true_strain = math.log(1 + at_yield_engg_strain)
        calculated_values.append(f"At yield true strain: {at_yield_true_strain:.8f}")
    else:
        at_yield_true_strain = None
        calculation_errors.append("At yield true strain: Cannot calculate log (1+engg strain <= 0).")

    # 5) At yield true stress = yield strength*(1 + at yield engg strain)
    if yield_strength is not None and at_yield_engg_strain is not None:
        at_yield_true_stress = yield_strength * (1 + at_yield_engg_strain)
        calculated_values.append(f"At yield true stress: {at_yield_true_stress:.4f}")
    else:
        at_yield_true_stress = None
        calculation_errors.append("At yield true stress: Missing Yield Strength or At yield engineering strain.")

    # 6) At UTS true strain = log base e ( 1+ %elongation/100)
    if nominal_strain_at_uts is not None and (1 + nominal_strain_at_uts) > 0:
        at_uts_true_strain = math.log(1 + nominal_strain_at_uts)
        calculated_values.append(f"At UTS true strain: {at_uts_true_strain:.8f}")
    else:
        at_uts_true_strain = None
        calculation_errors.append("At UTS true strain: Cannot calculate log (1+nominal strain at UTS <= 0).")

    # 7) At UTS true stress = UTS * (1+%elongation/100)
    if uts is not None and nominal_strain_at_uts is not None:
        at_uts_true_stress = uts * (1 + nominal_strain_at_uts)
        calculated_values.append(f"At UTS true stress: {at_uts_true_stress:.4f}")
    else:
        at_uts_true_stress = None
        calculation_errors.append("At UTS true stress: Missing UTS or Nominal strain at UTS.")

    # 8) plastic strain at yield = At yield true strain - (At yield true stress/youngs modulus)
    if at_yield_true_strain is not None and at_yield_true_stress is not None and youngs_modulus is not None and youngs_modulus != 0:
        plastic_strain_at_yield = at_yield_true_strain - (at_yield_true_stress / youngs_modulus)
        calculated_values.append(f"Plastic strain at yield: {plastic_strain_at_yield:.8f}")
    else:
        plastic_strain_at_yield = None
        calculation_errors.append("Plastic strain at yield: Missing required values for calculation or Young's Modulus is zero.")

    # 9) Plastic strain at UTS = At UTS true strain-(at UTS true stress/youngs modulus)
    if at_uts_true_strain is not None and at_uts_true_stress is not None and youngs_modulus is not None and youngs_modulus != 0:
        plastic_strain_at_uts = at_uts_true_strain - (at_uts_true_stress / youngs_modulus)
        calculated_values.append(f"Plastic strain at UTS: {plastic_strain_at_uts:.8f}")
    else:
        plastic_strain_at_uts = None
        calculation_errors.append("Plastic strain at UTS: Missing required values for calculation or Young's Modulus is zero.")


    # --- Construct Output Content ---
    output_content = f"Material: {material_name}\n"
    output_content += f"Manufacturing Process: {mfg_process}\n"
    output_content += f"Applications: {applications}\n\n"

    output_content += "--- Input Properties (from selected row) ---\n"
    output_content += f"Yield strength: {yield_strength if yield_strength is not None else 'N/A'}\n"
    output_content += f"UTS: {uts if uts is not None else 'N/A'}\n"
    output_content += f"%elongation: {percent_elongation if percent_elongation is not None else 'N/A'}\n"
    output_content += f"Young's modulus: {youngs_modulus if youngs_modulus is not None else 'N/A'}\n\n"

    output_content += "--- Calculated Mechanical Properties ---\n"
    output_content += "\n".join(calculated_values)

    if calculation_errors:
        output_content += "\n\n--- Calculation Warnings/Errors ---\n"
        output_content += "\n".join(calculation_errors)


    # Open a file dialog to choose where to save the file
    initial_filename = f"{material_name.replace(' ', '_')}_calculated_details.txt"
    file_path = filedialog.asksaveasfilename(
        defaultextension=".txt",
        filetypes=[("Text files", "*.txt"), ("All files", "*.*")],
        initialfile=initial_filename
    )

    if file_path:
        try:
            with open(file_path, "w") as f:
                f.write(output_content)
            messagebox.showinfo("Download Complete", f"Calculated details saved to:\n{os.path.basename(file_path)}")
        except Exception as e:
            messagebox.showerror("Download Error", f"Failed to save file: {e}")

# Function to enable/disable download button based on selection
def check_download_button_state(*args):
    if tree.selection():
        download_data_button.config(state='normal')
    else:
        download_data_button.config(state='disabled')

# Bind the Treeview selection event to the state checker
tree.bind('<<TreeviewSelect>>', check_download_button_state)

# --------- Add Data Button to Main Window ---------
add_data_button = ttk.Button(
    search_filter_add_frame, # Placed in the combined search/filter/add frame
    text="Add Data",
    command=add_data,
    style='AddData.TButton'
)
add_data_button.pack(side='right', padx=(10, 5)) # Pack it to the right of controls

# --------- Download Data Button to Main Window ---------
download_data_button = ttk.Button(
    search_filter_add_frame, # Placed in the combined search/filter/add frame
    text="Download Details",
    command=download_selected_row_details,
    style='Download.TButton',
    state='disabled' # Initially disabled until a row is selected
)
download_data_button.pack(side='right', padx=(5, 10))

# Initial check for download button state
check_download_button_state()

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import tkinter as tk
#       2 from tkinter import ttk, messagebox, filedialog
# ----> 3 import pandas as pd
#       4 import os # Import os module for path operations
#       5 import math # Import math module for log
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import tkinter as tk
from tkinter import ttk, messagebox, filedialog
import pandas as pd
import os # Import os module for path operations
import math # Import math module for log

# Load the Excel data
try:
    df = pd.read_excel("sample_material_data.xlsx")
except FileNotFoundError:
    messagebox.showerror("Error", "sample_material_data.xlsx not found. Please make sure the file is in the same directory.")
    exit()

# Create the main window
root = tk.Tk()
root.title("Material Data")
root.geometry("1250x750")
root.configure(bg="#f0f0f0")

# Style configuration
style = ttk.Style(root)
style.theme_use('clam')

style.configure(
    "Treeview",
    background="white",
    foreground="black",
    rowheight=25,
    fieldbackground="white",
    font=('Segoe UI', 10)
)

style.map(
    'Treeview',
    background=[('selected', '#347083')],
    foreground=[('selected', 'white')]
)

style.configure(
    "Treeview.Heading",
    font=('Segoe UI', 11, 'bold'),
    background="#4a7abc",
    foreground="white"
)

# Button styles for material type toggling
style.configure('Material.TButton', background='#f0f0f0', foreground='black')
style.configure('SelectedMaterial.TButton', background='#87ceeb', foreground='black')

# Add Data Button Style
style.configure('AddData.TButton', background='#28a745', foreground='white', font=('Segoe UI', 10, 'bold'))
style.map('AddData.TButton', background=[('active', '#218838')])

# Download Button Style
style.configure('Download.TButton', background='#007bff', foreground='white', font=('Segoe UI', 10, 'bold'))
style.map('Download.TButton', background=[('active', '#0056b3')])


# --------- Main Frame Setup ---------
main_frame = ttk.Frame(root, padding=10)
main_frame.pack(fill='both', expand=True)

# --------- Search & Filter Frame ---------
search_filter_add_frame = ttk.Frame(main_frame)
search_filter_add_frame.pack(fill='x', pady=(0, 10))

# Search & Filter controls sub-frame (to group them on the left)
search_filter_controls_frame = ttk.Frame(search_filter_add_frame)
search_filter_controls_frame.pack(side='left', fill='x', expand=True)


# Search by Material
ttk.Label(search_filter_controls_frame, text="Search Material:", font=('Segoe UI', 11)).pack(side='left', padx=(0, 5))

search_var = tk.StringVar()
search_entry = ttk.Entry(search_filter_controls_frame, textvariable=search_var, font=('Segoe UI', 11), width=20)
search_entry.pack(side='left', padx=(0, 10))

# Sorting dropdown
ttk.Label(search_filter_controls_frame, text="Sort by:", font=('Segoe UI', 11)).pack(side='left')

sort_var = tk.StringVar()
sort_options = ["None","Youngs modulus", "Poissons ratio", "UTS", "Yield strength", "Endurance Strength"]

sort_combobox = ttk.Combobox(
    search_filter_controls_frame,
    textvariable=sort_var,
    values=sort_options,
    state='readonly',
    width=15,
    font=('Segoe UI', 10)
)
sort_combobox.set("Select a column")
sort_combobox.pack(side='left', padx=(0, 10))

# Manufacturing Process Filter
ttk.Label(search_filter_controls_frame, text="Filter Mfg. Process:", font=('Segoe UI', 11)).pack(side='left')

mfg_process_var = tk.StringVar()
mfg_process_options = ["All"] + sorted(df['Manufacturing process'].dropna().unique().tolist())

mfg_process_combobox = ttk.Combobox(
    search_filter_controls_frame,
    textvariable=mfg_process_var,
    values=mfg_process_options,
    state='readonly',
    width=15,
    font=('Segoe UI', 10)
)
mfg_process_combobox.set("All")
mfg_process_combobox.pack(side='left', padx=(0, 10))

# Applications Filter
ttk.Label(search_filter_controls_frame, text="Filter Applications:", font=('Segoe UI', 11)).pack(side='left')

applications_var = tk.StringVar()
applications_options = ["All"] + sorted(df['Applications'].dropna().unique().tolist())

applications_combobox = ttk.Combobox(
    search_filter_controls_frame,
    textvariable=applications_var,
    values=applications_options,
    state='readonly',
    width=15,
    font=('Segoe UI', 10)
)
applications_combobox.set("All")
applications_combobox.pack(side='left')

# --------- Treeview Widget Setup ---------
tree = ttk.Treeview(main_frame, columns=list(df.columns), show='headings')

for col in df.columns:
    tree.heading(col, text=col)
    tree.column(col, width=110, anchor='center')

vsb = ttk.Scrollbar(main_frame, orient="vertical", command=tree.yview)
hsb = ttk.Scrollbar(main_frame, orient="horizontal", command=tree.xview)

tree.configure(yscrollcommand=vsb.set, xscrollcommand=hsb.set)

vsb.pack(side='right', fill='y')
tree.pack(fill='both', expand=True)

# --------- Material Type Buttons Frame (Above horizontal scrollbar) ---------
material_type_frame = ttk.Frame(main_frame)
material_type_frame.pack(fill='x', pady=(10, 5))

ttk.Label(material_type_frame, text="Filter by Material Type:", font=('Segoe UI', 11, 'bold')).pack(side='left', padx=(0, 10))

material_type_filter = tk.StringVar(value="")  # No filter initially

material_types = ["Steel", "Aluminum", "Cast Iron"]
selected_material_button = None  # To track which button is selected


def material_type_button_clicked(mat):
    global selected_material_button
    current = material_type_filter.get()

    if current == mat:
        # Deselect if same button clicked again
        material_type_filter.set("")
        if selected_material_button:
            selected_material_button.configure(style='Material.TButton')
            selected_material_button = None
    else:
        # Select new button and update styles
        material_type_filter.set(mat)

        if selected_material_button:
            selected_material_button.configure(style='Material.TButton')

        for btn in material_type_buttons:
            if btn['text'] == mat:
                btn.configure(style='SelectedMaterial.TButton')
                selected_material_button = btn
                break

    update_view()


material_type_buttons = []
for mat in material_types:
    btn = ttk.Button(
        material_type_frame,
        text=mat,
        width=12,
        style='Material.TButton',
        command=lambda m=mat: material_type_button_clicked(m)
    )
    btn.pack(side='left', padx=5)
    material_type_buttons.append(btn)

hsb.pack(side='bottom', fill='x')  # Horizontal scrollbar at bottom

# --------- Function to Display Data in Treeview ---------
def display_data(dataframe):
    tree.delete(*tree.get_children())
    for i, (_, row) in enumerate(dataframe.iterrows()):
        tag = 'evenrow' if i % 2 == 0 else 'oddrow'
        tree.insert('', 'end', values=list(row), tags=(tag,))
    tree.tag_configure('evenrow', background='white')
    tree.tag_configure('oddrow', background='#e6f2ff')


# Initial load of all data
display_data(df)


# --------- Update View on Filters/Search/Sort ---------
def update_view(*args):
    global df # Ensure we use the global df

    filtered_df = df.copy()

    # Filter by Material search text
    search_text = search_var.get().strip().lower()
    if search_text:
        filtered_df = filtered_df[filtered_df['Material'].str.lower().str.contains(search_text, na=False)]

    # Filter Manufacturing Process
    mfg_value = mfg_process_var.get()
    if mfg_value != "All":
        filtered_df = filtered_df[filtered_df['Manufacturing process'] == mfg_value]

    # Filter Applications
    app_value = applications_var.get()
    if app_value != "All":
        filtered_df = filtered_df[filtered_df['Applications'] == app_value]

    # Filter Material Type from buttons
    mat_type = material_type_filter.get()
    if mat_type:
        filtered_df = filtered_df[filtered_df['Material'].str.contains(mat_type, case=False, na=False)]

    # Sort data if valid column selected
    sort_column = sort_var.get()
    if sort_column and sort_column in sort_options and sort_column != "None":
        try:
            # Convert to numeric for proper sorting if applicable
            if sort_column in ["Youngs modulus", "Poissons ratio", "UTS", "Yield strength", "Endurance Strength"]:
                # Ensure the column exists before attempting to sort
                if sort_column in filtered_df.columns:
                    filtered_df = filtered_df.copy() # Avoid SettingWithCopyWarning
                    # Use a custom sort key to handle mixed types by coercing to numeric,
                    # placing non-numeric values (NaN after coerce) at the end.
                    filtered_df[sort_column] = pd.to_numeric(filtered_df[sort_column], errors='coerce')
                    filtered_df = filtered_df.sort_values(by=sort_column, ascending=True, na_position='last')
                else:
                    messagebox.showwarning("Column Not Found", f"Sorting column '{sort_column}' not found in current data.")
            else:
                filtered_df = filtered_df.sort_values(by=sort_column, ascending=True)
        except Exception as e:
            messagebox.showerror("Sorting Error", f"Could not sort by {sort_column}: {e}")

    display_data(filtered_df)
    check_download_button_state() # Update download button state after view update


# Bind events to trigger filtering and sorting
search_var.trace_add('write', update_view)
sort_combobox.bind('<<ComboboxSelected>>', update_view)
mfg_process_combobox.bind('<<ComboboxSelected>>', update_view)
applications_combobox.bind('<<ComboboxSelected>>', update_view)


# --------- Add Data Functionality ---------
def add_data():
    add_window = tk.Toplevel(root)
    add_window.title("Add New Material Data")
    add_window.geometry("500x600")
    add_window.transient(root) # Make it appear on top of the main window
    add_window.grab_set() # Disable interaction with the main window

    form_frame = ttk.Frame(add_window, padding=20)
    form_frame.pack(fill='both', expand=True)

    entries = {}
    for i, col in enumerate(df.columns):
        ttk.Label(form_frame, text=f"{col}:", font=('Segoe UI', 10)).grid(row=i, column=0, sticky='w', pady=5, padx=5)
        entry = ttk.Entry(form_frame, width=40, font=('Segoe UI', 10))
        entry.grid(row=i, column=1, sticky='ew', pady=5, padx=5)
        entries[col] = entry

    def submit_new_data():
        global df
        new_row_data = {}
        for col, entry_widget in entries.items():
            value = entry_widget.get().strip()
            # Basic type conversion for numeric columns, handle errors gracefully
            if col in ["Youngs modulus", "Poissons ratio", "UTS", "Yield strength", "Endurance Strength", "%EL"]: # Changed %elongation to %EL
                try:
                    new_row_data[col] = float(value) if value else None # Convert to float, None if empty
                except ValueError:
                    messagebox.showerror("Input Error", f"Please enter a valid number for '{col}'.")
                    return
            else:
                new_row_data[col] = value if value else None # Store None for empty strings

        # Create a new DataFrame from the new row
        new_row_df = pd.DataFrame([new_row_data])

        # Append the new row to the main DataFrame
        df = pd.concat([df, new_row_df], ignore_index=True)

        # Save the updated DataFrame back to Excel
        try:
            df.to_excel("sample_material_data.xlsx", index=False)
            messagebox.showinfo("Success", "New data added successfully and saved to Excel.")
            update_view() # Refresh the Treeview
            add_window.destroy() # Close the add data window
        except Exception as e:
            messagebox.showerror("Save Error", f"Could not save data to Excel: {e}")

    submit_button = ttk.Button(
        form_frame,
        text="Add Data",
        command=submit_new_data,
        style='AddData.TButton'
    )
    submit_button.grid(row=len(df.columns), column=0, columnspan=2, pady=20)


# --------- Download Data Functionality ---------
def download_selected_row_details():
    selected_item = tree.selection()
    if not selected_item:
        messagebox.showwarning("No Selection", "Please select a row to download details.")
        return

    # Get the values of the selected row
    values = tree.item(selected_item, 'values')
    
    # Create a dictionary of the selected row data using column names
    selected_row_dict = dict(zip(df.columns, values))

    # --- Extract required properties ---
    material_name = selected_row_dict.get('Material', 'N/A')
    mfg_process = selected_row_dict.get('Manufacturing process', 'N/A')
    applications = selected_row_dict.get('Applications', 'N/A')

    # Convert extracted values to float, handling potential missing or non-numeric data
    try:
        yield_strength = float(selected_row_dict.get('Yield strength')) if selected_row_dict.get('Yield strength') is not None else None
        uts = float(selected_row_dict.get('UTS')) if selected_row_dict.get('UTS') is not None else None
        # Changed from '%elongation' to '%EL'
        percent_elongation = float(selected_row_dict.get('%EL')) if selected_row_dict.get('%EL') is not None else None 
        youngs_modulus = float(selected_row_dict.get('Youngs modulus')) if selected_row_dict.get('Youngs modulus') is not None else None
    except ValueError:
        messagebox.showerror("Data Error", "Could not convert one or more required properties to numbers. Please check the data in the Excel file.")
        return

    # --- Perform Calculations ---
    calculated_values = []
    calculation_errors = []

    # 1) Nominal strain at yield = yield strength / young's modulus
    if yield_strength is not None and youngs_modulus is not None and youngs_modulus != 0:
        nominal_strain_at_yield = yield_strength / youngs_modulus
        calculated_values.append(f"Nominal strain at yield: {nominal_strain_at_yield:.9f}")
    else:
        nominal_strain_at_yield = None
        calculation_errors.append("Nominal strain at yield: Missing Yield Strength or Young's Modulus or Young's Modulus is zero.")

    # 2) Nominal strain at UTS = %elongation/100
    if percent_elongation is not None:
        nominal_strain_at_uts = percent_elongation / 100.0
        calculated_values.append(f"Nominal strain at UTS: {nominal_strain_at_uts:.9f}")
    else:
        nominal_strain_at_uts = None
        calculation_errors.append("Nominal strain at UTS: Missing %EL.") # Changed message

    # 3) At yield engineering strain = Nominal strain at yield
    at_yield_engg_strain = nominal_strain_at_yield
    if at_yield_engg_strain is not None:
        calculated_values.append(f"At yield engineering strain: {at_yield_engg_strain:.9f}")
    else:
        calculated_values.append("At yield engineering strain: Not calculable (see above).")

    # 4) At yield true strain = log base e (1+at yield engineering strain)
    if at_yield_engg_strain is not None and (1 + at_yield_engg_strain) > 0:
        at_yield_true_strain = math.log(1 + at_yield_engg_strain)
        calculated_values.append(f"At yield true strain: {at_yield_true_strain:.9f}")
    else:
        at_yield_true_strain = None
        calculation_errors.append("At yield true strain: Cannot calculate log (1+engg strain <= 0).")

    # 5) At yield true stress = yield strength*(1 + at yield engg strain)
    if yield_strength is not None and at_yield_engg_strain is not None:
        at_yield_true_stress = yield_strength * (1 + at_yield_engg_strain)
        calculated_values.append(f"At yield true stress: {at_yield_true_stress:.6f}")
    else:
        at_yield_true_stress = None
        calculation_errors.append("At yield true stress: Missing Yield Strength or At yield engineering strain.")

    # 6) At UTS true strain = log base e ( 1+ %elongation/100)
    if nominal_strain_at_uts is not None and (1 + nominal_strain_at_uts) > 0:
        at_uts_true_strain = math.log(1 + nominal_strain_at_uts)
        calculated_values.append(f"At UTS true strain: {at_uts_true_strain:.9f}")
    else:
        at_uts_true_strain = None
        calculation_errors.append("At UTS true strain: Cannot calculate log (1+nominal strain at UTS <= 0).")

    # 7) At UTS true stress = UTS * (1+%elongation/100)
    if uts is not None and nominal_strain_at_uts is not None:
        at_uts_true_stress = uts * (1 + nominal_strain_at_uts)
        calculated_values.append(f"At UTS true stress: {at_uts_true_stress:.6f}")
    else:
        at_uts_true_stress = None
        calculation_errors.append("At UTS true stress: Missing UTS or Nominal strain at UTS.")

    # 8) Plastic strain at yield = At yield true strain - (At yield true stress/youngs modulus)
    if at_yield_true_strain is not None and at_yield_true_stress is not None and youngs_modulus is not None and youngs_modulus != 0:
        plastic_strain_at_yield = at_yield_true_strain - (at_yield_true_stress / youngs_modulus)
        calculated_values.append(f"Plastic strain at yield: {plastic_strain_at_yield:.9f}")
    else:
        plastic_strain_at_yield = None
        calculation_errors.append("Plastic strain at yield: Missing required values for calculation or Young's Modulus is zero.")

    # 9) Plastic strain at UTS = At UTS true strain-(at UTS true stress/youngs modulus)
    if at_uts_true_strain is not None and at_uts_true_stress is not None and youngs_modulus is not None and youngs_modulus != 0:
        plastic_strain_at_uts = at_uts_true_strain - (at_uts_true_stress / youngs_modulus)
        calculated_values.append(f"Plastic strain at UTS: {plastic_strain_at_uts:.9f}")
    else:
        plastic_strain_at_uts = None
        calculation_errors.append("Plastic strain at UTS: Missing required values for calculation or Young's Modulus is zero.")


    # --- Construct Output Content ---
    output_content = f"Material: {material_name}\n"
    output_content += f"Manufacturing Process: {mfg_process}\n"
    output_content += f"Applications: {applications}\n\n"

    output_content += "--- Input Properties (from selected row) ---\n"
    output_content += f"Yield strength: {yield_strength if yield_strength is not None else 'N/A'}\n"
    output_content += f"UTS: {uts if uts is not None else 'N/A'}\n"
    output_content += f"%EL: {percent_elongation if percent_elongation is not None else 'N/A'}\n" # Changed %elongation to %EL
    output_content += f"Young's modulus: {youngs_modulus if youngs_modulus is not None else 'N/A'}\n\n"

    output_content += "--- Calculated Mechanical Properties ---\n"
    output_content += "\n".join(calculated_values)

    if calculation_errors:
        output_content += "\n\n--- Calculation Warnings/Errors ---\n"
        output_content += "\n".join(calculation_errors)


    # Open a file dialog to choose where to save the file
    initial_filename = f"{material_name.replace(' ', '_')}_calculated_details.txt"
    file_path = filedialog.asksaveasfilename(
        defaultextension=".txt",
        filetypes=[("Text files", "*.txt"), ("All files", "*.*")],
        initialfile=initial_filename
    )

    if file_path:
        try:
            with open(file_path, "w") as f:
                f.write(output_content)
            messagebox.showinfo("Download Complete", f"Calculated details saved to:\n{os.path.basename(file_path)}")
        except Exception as e:
            messagebox.showerror("Download Error", f"Failed to save file: {e}")

# Function to enable/disable download button based on selection
def check_download_button_state(*args):
    if tree.selection():
        download_data_button.config(state='normal')
    else:
        download_data_button.config(state='disabled')

# Bind the Treeview selection event to the state checker
tree.bind('<<TreeviewSelect>>', check_download_button_state)

# --------- Add Data Button to Main Window ---------
add_data_button = ttk.Button(
    search_filter_add_frame, # Placed in the combined search/filter/add frame
    text="Add Data",
    command=add_data,
    style='AddData.TButton'
)
add_data_button.pack(side='right', padx=(10, 5)) # Pack it to the right of controls

# --------- Download Data Button to Main Window ---------
download_data_button = ttk.Button(
    search_filter_add_frame, # Placed in the combined search/filter/add frame
    text="Download Details",
    command=download_selected_row_details,
    style='Download.TButton',
    state='disabled' # Initially disabled until a row is selected
)
download_data_button.pack(side='right', padx=(5, 10))

# Initial check for download button state
check_download_button_state()

root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 9
#       7 # Load the Excel data
#       8 try:
# ----> 9     df = pd.read_excel("sample_material_data.xlsx")
#      10 except FileNotFoundError:
#      11     messagebox.showerror("Error", "sample_material_data.xlsx not found. Please make sure the file is in the same directory.")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_base.py:1567, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1564 self.engine = engine
#    1565 self.storage_options = storage_options
# -> 1567 self._reader = self._engines[engine](
#    1568     self._io,
#    1569     storage_options=storage_options,
#    1570     engine_kwargs=engine_kwargs,
#    1571 )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\excel\_openpyxl.py:552, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     534 @doc(storage_options=_shared_docs["storage_options"])
#     535 def __init__(
#     536     self,
#    (...)    539     engine_kwargs: dict | None = None,
#     540 ) -> None:
#     541     """
#     542     Reader using openpyxl engine.
#     543
#    (...)    550         Arbitrary keyword arguments passed to excel engine.
#     551     """
# --> 552     import_optional_dependency("openpyxl")
#     553     super().__init__(
#     554         filepath_or_buffer,
#     555         storage_options=storage_options,
#     556         engine_kwargs=engine_kwargs,
#     557     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\compat\_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     136 except ImportError:
#     137     if errors == "raise":
# --> 138         raise ImportError(msg)
#     139     return None
#     141 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.

# %%
print("ggrgr")
# Out:
# ggrgr

# %%
pip install pandas
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Collecting pandas
#   Downloading pandas-2.3.0-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.3.0-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kkd740522\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\kkd740522\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.0-cp313-cp313-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 2.9 MB/s eta 0:00:04
#    -- ------------------------------------- 0.8/11.0 MB 3.1 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.6/11.0 MB 2.4 MB/s eta 0:00:04
#    ------- -------------------------------- 2.1/11.0 MB 2.8 MB/s eta 0:00:04
#    -------- ------------------------------- 2.4/11.0 MB 2.0 MB/s eta 0:00:05
#    ------------ --------------------------- 3.4/11.0 MB 2.5 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.5/11.0 MB 2.6 MB/s eta 0:00:03
#    ------------------- -------------------- 5.2/11.0 MB 2.7 MB/s eta 0:00:03
#    ------------------------------- -------- 8.7/11.0 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 5.0 MB/s eta 0:00:00
# Downloading numpy-2.3.0-cp313-cp313-win_amd64.whl (12.7 MB)
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#    ------------ --------------------------- 3.9/12.7 MB 21.7 MB/s eta 0:00:01
#    ------------- -------------------------- 4.2/12.7 MB 21.6 MB/s eta 0:00:01
#    -------------------- ------------------- 6.6/12.7 MB 10.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 9.2/12.7 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.7 MB 12.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.7/12.7 MB 10.8 MB/s eta 0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-2.3.0 pandas-2.3.0 pytz-2025.2 tzdata-2025.2
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: C:\Users\kkd740522\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip
